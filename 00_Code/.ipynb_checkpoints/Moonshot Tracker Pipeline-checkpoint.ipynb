# %% [markdown]
# <h1> Data pipeline for UNDP Energy Moonshot Tracker </h1>

# %% [markdown]
# This notebook executes the full data pipeline for ingesting the country-level energy project outputs alongside country metadata, data from the transparency portal API, donor information, and conversion factors based on our methodology to evaluate counts for direct and indirect beneficiaries. This data is then analyzed, visualized, and exported.

# %%
import pandas as pd
import os
import numpy as np
import warnings
import random
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import json
from tqdm import tqdm
import ast
import countrynames
import math
from urllib.request import urlopen
import re
import xlsxwriter
import csv
from functools import reduce
import openai
import os
from dotenv import load_dotenv
import hashlib
from urllib.parse import urlparse
import numbers

# %% [markdown]
# <h2> Prepare data (Projects, Outputs, Donors, and Countries) </h2>

# %% [markdown]
# <h4> Country metadata and tracker </h4>

# %%
#country metadata
countryMetadata=pd.read_csv("../01_Input/03_Country Meta/countryMetadataInput.csv")

#print(countryMetadata)

countryMetadata.to_csv("../02_Output/03_Countries/countryMetadata.csv")

print(countryMetadata["Country Name"].tolist())
# Out:
# ['Afghanistan', 'Åland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon, Republic of', 'Canada', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Dem. Rep. of the Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, DPR', 'Korea, Republic of', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Federated States of Micronesia', 'Moldova Republic', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'North Macedonia', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Prog for Palestinian People', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Réunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Barthélemy', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome & Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the South Sandwich Islands', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Svalbard and Jan Mayen', 'Sweden', 'Switzerland', 'Syria', 'Tajikistan', 'United Republic of Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad & Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom of Great Britain and Northern Ireland', 'United States of America', 'United States Minor Outlying Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Viet Nam', 'British Virgin Islands', 'US Virgin Islands', 'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe']

# %% [markdown]
# <h4> Create dataframes for projects and outputs </h4>

# %%
##analyze projects included

countryList=[]

projectDict={}
outputDict={}

file_path="../01_Input/00_CO Validation/"

def countryNameToCode(countryName):         
    try:
        countryCode=countryMetadata.loc[countryMetadata['Country Name'] == countryName, 'Country Code'].values[0]
        if countryCode not in countryList:
            countryList.append(countryCode)
    except:
        countryCode="NA"
        print(f"Missing country metadata for: {countryName}")   
    return countryCode

for root, directories, files in os.walk(file_path):
    count=0
    for name in files:
        if "$" not in name and "DS" not in name and "Energy Projects" in name:            
            try:
                df=pd.read_excel(file_path+name, sheet_name="Projects (3)")
            except:
                print(name + " can't read projects(3) df")
                
            countryName=name.split(" -")[0]
            countryCode=countryNameToCode(countryName)
            
            
            projectId="none"
            
            for index,row in df.iterrows():
                
                if "Country" in row:
                    if not pd.isna(row["Country"]):
                        print(row["Country"])
                        countryName=row["Country"]      
                        countryCode=countryNameToCode(countryName)

                #if there is something in the id column, set the current project info
                if str(row["Project ID"])!="nan" and len(str(row["Project ID"]).strip())>0:
                    projectId=row["Project ID"]
                    #check if id works (need to update this to handle multi-ids)
                    if str(projectId).replace('.','').strip().isnumeric() or "missing" in str(projectId):
                        #print(projectId)
                        pass
                    
                    budget=0
                    if "Budget" in row:
                        budget=row["Budget"]
                    elif "Budget (USD)" in row:
                        budget=row["Budget (USD)"]
                    if "$" in str(budget):
                        budget=budget.split("$")[-1]
                    try:
                        budget=float(budget)
                    except:
                        #print(budget,countryName)
                        budget=-1##just a flag that the budget is tbd
                    try:
                        vf=row["VF or Non-VF"]
                    except:
                        ###this is temp
                        if len(str(projectId))<6:
                            vf="VF"
                        else:
                            vf="Non-VF"
                    title=row["Title"]
                    link=row["Link"]
                    try:
                        donors=row["Donors"]
                    except:
                        donors=""
                    
                if projectId!="none":
                    
                    count+=1

                    if str(projectId) not in projectDict:
                        projectDict[str(projectId)]={"Project ID":projectId,
                                                "Project Title":title,
                                                "Budget":budget,
                                                "Country":countryName,
                                                "Country Code":countryCode,
                                                "Link":link,
                                                "Donors":donors,
                                                "VF or Non-VF":vf,
                                                "Output Count":1}
                        newOutputId=str(projectId)+"-1"
                    else:
                        projectDict[str(projectId)]["Output Count"]+=1
                        newOutputId=str(projectId)+"-"+str(projectDict[str(projectId)]["Output Count"])

                    newOutput=row
                    newOutput["Beneficiary Category"]=str(newOutput["Beneficiary Category"]).strip()
                    projectMeta=projectDict[str(projectId)]
                    newOutput["Output ID"]=newOutputId
                    newOutput["Project ID"]=projectMeta["Project ID"]
                    newOutput["Title"]=projectMeta["Project Title"]
                    newOutput["Country Code"]=countryCode
                    newOutput["Country"]=projectMeta["Country"]
                    newOutput["Link"]=projectMeta["Link"]
                    newOutput["Budget"]=projectMeta["Budget"]
                    newOutput["VF or Non-VF"]=projectMeta["VF or Non-VF"]


                    outputDict[newOutputId]=newOutput
                else:
                    print(countryCode," - ",projectId," - ", title," - bad ID")
                            

projectDf=pd.DataFrame.from_records([*projectDict.values()])
outputDf=pd.DataFrame.from_records([*outputDict.values()])




projectDf.to_csv("../02_Output/01_Projects/projectDfValidation.csv")
outputDf.to_csv("../02_Output/02_Outputs/outputDfValidation.csv")
print(count)
# Out:
# Samoa
# Samoa
# Niue
# Missing country metadata for: Nature Hub
# Missing country metadata for: Bureau Policy & Prog Support
# Barbados
# Fiji (+10 member countries of Pacific Island Development Forum)
# Missing country metadata for: Fiji (+10 member countries of Pacific Island Development Forum)
# Vanuatu
# Tuvalu
# Nauru
# Kiribati
# Federated States of Micronesia
# Vanuatu
# Mauritius
# Mauritius
# Mauritius
# Missing country metadata for: New York
# 1179

# %%
#calculate project and output stats
projectList=projectDf["Project ID"].tolist()
print(len(projectList), "projects")
print(len(outputDict), "outputs")
print(projectDf["Budget"].sum(),"budget")
# Out:
# 392 projects
# 1179 outputs
# 4222434948.6049185 budget

# %% [markdown]
# <h2> Process dataframes (Projects, Outputs, Donors, and Countries) </h2>

# %% [markdown]
# <h4> Clean up outputDf </h4>

# %%
#keep only certain headers (need to clean data to correct names)

headers=["Project ID","Output ID","Country Code","Title","Link","Budget","Beneficiary Category","Indicator","Baseline","Target","Notes","Donors","Gender (% female)","Flagship","Tag","SEH Taxonomy","RISE Taxonomy","Technology","Category","Policy-taxonomy","VF or Non-VF"]      

outputDf=outputDf[outputDf.columns[outputDf.columns.isin(headers)]]

# %%
#add country metadata (region and other groupings), country code, to outputDf
outputDfComplete=pd.merge(outputDf,countryMetadata,on="Country Code",how='left')
outputDfComplete.columns.values
# Out:
# array(['Project ID', 'Title', 'Link', 'Budget', 'Beneficiary Category',
#        'Indicator', 'Baseline', 'Target', 'Notes', 'Donors',
#        'Gender (% female)', 'VF or Non-VF', 'Tag', 'SEH Taxonomy',
#        'RISE Taxonomy', 'Flagship', 'Technology', 'Output ID',
#        'Country Code', 'Category', 'Country Name', 'm49',
#        'continent-region', 'sub-region', 'sids-region', 'un-member',
#        'undp-sids', 'un-region', 'Region', 'Economy', 'LDC', 'SIDS',
#        'LLDC', 'HDI', 'Sahel'], dtype=object)

# %%
#donors for outputs could be updated to include atlas and pims data

# %% [markdown]
# <h2> Beneficiaries Conversion </h2>

# %% [markdown]
# <h4> direct conversion </h4>

# %%
#load Direct conversion Scores
directConversion=pd.read_csv("../01_Input/01_Methodology/Direct Conversion Factors.csv")
#HH data
HHdata=pd.read_csv("../01_Input/03_Country Meta/HHData.csv")
print(HHdata)
# Out:
#      Country or area Average household size (number of members)  \
# 0           Zimbabwe                                       4.02
# 1           Zimbabwe                                       4.08
# 2           Zimbabwe                                       4.16
# 3           Zimbabwe                                       4.04
# 4           Zimbabwe                                       4.15
# ...              ...                                        ...
# 1053         Albania                                       3.82
# 1054         Albania                                          4
# 1055         Albania                                       4.35
# 1056     Afghanistan                                       8.04
# 1057     Afghanistan                                       7.75
#
#      Data source category Reference date (dd/mm/yyyy)
# 0                    MICS                      1/7/19
# 1                     DHS                  27/09/2015
# 2                    MICS                      1/7/14
# 3                   IPUMS                      1/7/12
# 4                     DHS                  21/12/2010
# ...                   ...                         ...
# 1053                  DHS                  21/01/2009
# 1054                 MICS                      1/7/05
# 1055                 MICS                      1/7/00
# 1056                  DHS                  19/10/2015
# 1057                 MICS                      1/7/10
#
# [1058 rows x 4 columns]

# %%
#add column for direct beneficiaries convert
  
def getDirectFactor(category):
    try:
        return directConversion.loc[directConversion["Beneficiary Category"]==category,"Factor"].values[0]
    except:
        return 0
    
def convertHH(row):
    target=str(row["Target"]).replace(',', '')
    if "HH" in target:
        try:
            householdSize=HHdata[HHdata["Country or area"]==row["Country Name"]].iloc[0]["Average household size (number of members)"]
        except:
            householdSize=5
            print("no HH for", row["Country Name"])
        try:
            return int(target.split("HH")[0])*float(householdSize)
        except:
            print(target,"contains HH but broken")
            return target
    else:
        try: 
            return int(target)
        except:
            print(target,row["Country Name"],"incorrect format") ##this will show all nonnumeric targets
            return target
    
outputDfComplete["Direct Conversion Factor"]=outputDfComplete["Beneficiary Category"].apply(lambda x: getDirectFactor(x))
   
outputDfComplete['Target'] =  outputDfComplete.apply(convertHH, axis=1)

outputDfComplete["Direct Beneficiaries"]=(pd.to_numeric(outputDfComplete['Target'], errors='coerce').fillna(0)-pd.to_numeric(outputDfComplete['Baseline'], errors='coerce').fillna(0))*outputDfComplete["Direct Conversion Factor"]
outputDfComplete["Direct Beneficiaries"] = pd.to_numeric(outputDfComplete["Direct Beneficiaries"], errors='coerce')
# Out:
# 4936.0 Zambia incorrect format
# 13780.0 Zambia incorrect format
# 0.45 Zambia incorrect format
# 810000.0 Zambia incorrect format
# 1002.0 Zambia incorrect format
# 0.15 Zambia incorrect format
# 2.025 Malawi incorrect format
# nan Malawi incorrect format
# nan South Africa incorrect format
# 1.8 South Africa incorrect format
# 132 target Samoa incorrect format
# 0.73 Niue incorrect format
# no HH for Niue
# 0.264 MW Brazil incorrect format
# 20000.0 Jamaica incorrect format
# 0.01 Jamaica incorrect format
# 76.2 Jamaica incorrect format
# 15000000.0 Jamaica incorrect format
# 40.0 Jamaica incorrect format
# 5000.0 Jamaica incorrect format
# 1 new energy mix  Algeria incorrect format
# 0.2 Yemen incorrect format
# nan Belize incorrect format
# nan Belize incorrect format
# nan Belize incorrect format
# nan Belize incorrect format
# nan Belize incorrect format
# 160.0 Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Iran incorrect format
# 0.375 Iran incorrect format
# 1.5 Iran incorrect format
# 20000.0 Iran incorrect format
# 146167.0 Iran incorrect format
# 0.254 Iran incorrect format
# 2133.0 Iran incorrect format
# 100000.0 Iran incorrect format
# 0.02 Iran incorrect format
# nan Iran incorrect format
# nan Iran incorrect format
# nan Iran incorrect format
# 69.0 Colombia incorrect format
# 56.0 Colombia incorrect format
# 16571.0 Colombia incorrect format
# nan Colombia incorrect format
# nan Comoros incorrect format
# 0.449 Comoros incorrect format
# 358 363 Comoros incorrect format
# 0.07 Comoros incorrect format
# no HH for Moldova Republic
# no HH for Moldova Republic
# nan Moldova Republic incorrect format
# nan Moldova Republic incorrect format
# no HH for Moldova Republic
# nan Moldova Republic incorrect format
# nan Moldova Republic incorrect format
# 1. 2 drafts/amendments for the energy policy documents are developed consulted and presented to relevant authorities for further approval;
#
# 2. at least 10 draft regulatory documents developed consulted and presented for relevant authorities for approval   Moldova Republic incorrect format
# nan Moldova Republic incorrect format
# no HH for Moldova Republic
# nan Moldova Republic incorrect format
# 4.1.2. Target: 7
#
#
# 4.2.1.  Target: 215000 (Women: 64500/Men: 150500)
#
# 4.2.4. Target: 34
#
# 4.3.3.Target: 130 Moldova Republic incorrect format
# 3000000 consumers outreach (40% women)
# 60000 consumers (households )
# 4
# 1
# 3000000 people (40% women)
# 50 journalists system operators institutions and civil society representatives
# 60000 households prosumers and public sector entities
# 1500 households/apartments in MAB
# 1 established unified RNLC
#  Moldova Republic incorrect format
# 70% of the target beneficiaries are aware of gender transformative climate change interventions
# 83
# 6
#
# 12
#
# 30000
#
# 80 Moldova Republic incorrect format
# 1.3 Target: 1000000 EUR additional investment
# 1.5 Target: 150 new jobs
# 1.1.1 Target: 50 including 40% women
# 1.1.2 Target: 25 including 30% women
# 1.1.3 Target: 25
# 1.1.7 Target: National Sustainable Mobility Programme and Action Plan developed
# 2.1.2 Target: 100 including 50% women
# 3.1.3 Target: 3 eco-mobility startups supported Moldova Republic incorrect format
# nan Moldova Republic incorrect format
# 45000.0 Congo incorrect format
# nan Congo incorrect format
# 1602.0 Jordan incorrect format
# 7742000.0 Jordan incorrect format
# 1822.0 Jordan incorrect format
# 153000.0 Jordan incorrect format
# nan Jordan incorrect format
# nan Sierra Leone incorrect format
# nan Sierra Leone incorrect format
# nan Sierra Leone incorrect format
# nan Sierra Leone incorrect format
# 3000 Female Headed HH contains HH but broken
# nan Sierra Leone incorrect format
# 1000000.0 Uruguay incorrect format
# 5000.0 Uruguay incorrect format
# 100000.0 Uruguay incorrect format
# nan Uruguay incorrect format
# 1.018 Cyprus incorrect format
# 1100.0 Cyprus incorrect format
# 0.3 Cyprus incorrect format
# 340.0 Cyprus incorrect format
# 1.1 Suriname incorrect format
# 55 solar streetlight units Gambia incorrect format
# 0.095 Gambia incorrect format
# 2200000.0 Uganda incorrect format
# 1500.0 Uganda incorrect format
# 300000.0 Uganda incorrect format
# 300.0 Uganda incorrect format
# 100.0 Uganda incorrect format
# 6.0 Uganda incorrect format
# 200.0 Uganda incorrect format
# 500.0 Uganda incorrect format
# nan Uganda incorrect format
# 3.0 Botswana incorrect format
# 77.0 Botswana incorrect format
# nan Botswana incorrect format
# 200.0 Botswana incorrect format
# 750.0 Botswana incorrect format
# nan Botswana incorrect format
# 12.0 Botswana incorrect format
# 3-5 Ethiopia incorrect format
# nan Ethiopia incorrect format
# nan Ethiopia incorrect format
# nan Ethiopia incorrect format
# nan Ethiopia incorrect format
# Reduction of energy related GHG emissions by 2 million tons of CO2 equivalent Ethiopia incorrect format
# New regulations for enforcement of standards in place. Ethiopia incorrect format
# 15 million Ethiopia incorrect format
# 16836 (direct)
# 4905000 (indirect)
#  Ethiopia incorrect format
# 0.624 Ethiopia incorrect format
# nan Ethiopia incorrect format
# On a scale of 1 to 5 an average score of at least 4 is achieved.  Ethiopia incorrect format
# On a scale of 1 to 5 an average score of at least 4 is achieved.  Ethiopia incorrect format
# Appropriate climate-finance mechanisms identified and roadmap for their implementation prepared and approved Belarus incorrect format
# nan Bahrain incorrect format
# 134200.0 Nepal incorrect format
# 4.8 Nepal incorrect format
# 7470.0 Nepal incorrect format
# nan Nepal incorrect format
# 2734.0 Nepal incorrect format
# 3260.0 Nepal incorrect format
# 5.0 Papua New Guinea incorrect format
# 2.0 Papua New Guinea incorrect format
# 4.0 Papua New Guinea incorrect format
# nan Papua New Guinea incorrect format
# 43000.0 Papua New Guinea incorrect format
# 1.0 Papua New Guinea incorrect format
# 32439.375 Madagascar incorrect format
# 4986 MW added Venezuela incorrect format
# 0.059 Lesotho incorrect format
# nan Zimbabwe incorrect format
# 0.358 Zimbabwe incorrect format
# 160.0 Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# nan Ecuador incorrect format
# 267380.0 Pakistan incorrect format
# 3.0 Pakistan incorrect format
# 5.4 Pakistan incorrect format
# 7110.0 Pakistan incorrect format
# 32.0 Pakistan incorrect format
# 40.0 Pakistan incorrect format
# 5.0 Pakistan incorrect format
# 4.0 Pakistan incorrect format
# 1.0 Pakistan incorrect format
# 1.0 Pakistan incorrect format
# 1.0 Pakistan incorrect format
# 38.0 Pakistan incorrect format
# 5655190.0 nan incorrect format
# 50.0 nan incorrect format
# nan nan incorrect format
# nan nan incorrect format
# nan Honduras incorrect format
# installation of the 560 kW of PVs in 10 municipal buildings  Albania incorrect format
#   Albania incorrect format
# 1500.0 South Sudan incorrect format
# 0.2 South Sudan incorrect format
# 100.0 South Sudan incorrect format
# 1200.0 South Sudan incorrect format
# 25.0 South Sudan incorrect format
# 60.0 South Sudan incorrect format
# 5000.0 South Sudan incorrect format
# 2080000.0 South Sudan incorrect format
# 108 MW Ukraine incorrect format
# 29.9 MW Ukraine incorrect format
# 80 MW Ukraine incorrect format
# 90.6 MW Ukraine incorrect format
# 6.7 MW Ukraine incorrect format
# 314 municipalities Ukraine incorrect format
# 14 MW Ukraine incorrect format
# 40 MW Ukraine incorrect format
# 12 MW Ukraine incorrect format
# 6.5 MW Ukraine incorrect format
# 10.2 MW Ukraine incorrect format
# 0.515 Dem. Rep. of the Congo incorrect format
# no HH for Dem. Rep. of the Congo
# t Dem. Rep. of the Congo incorrect format
# no HH for Dem. Rep. of the Congo
# no HH for Dem. Rep. of the Congo
# 12263.0 Guinea incorrect format
# 0.122 Guinea incorrect format
# 0.094 Guinea incorrect format
# 1000.0 Guinea incorrect format
# 2.0 Guinea incorrect format
# 1000.0 Guinea incorrect format
# 400.0 Guinea incorrect format
# 5500.0 Guinea incorrect format
# nan Libya incorrect format
# - China incorrect format
# 4000.0 Maldives incorrect format
# 220.0 Maldives incorrect format
# nan Maldives incorrect format
# 105000.0 Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# 500.0 Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# nan Maldives incorrect format
# 430 buildings Bosnia and Herzegovina incorrect format
# 2.0 Paraguay incorrect format
# nan Paraguay incorrect format
# 100.0 Paraguay incorrect format
# 5564.0 Burkina Faso incorrect format
# 0.4 Burkina Faso incorrect format
# 4500.0 Burkina Faso incorrect format
# 27500.0 Burkina Faso incorrect format
# 4225.0 Burkina Faso incorrect format
# 490.0 Burkina Faso incorrect format
# 2.0 Burkina Faso incorrect format
# nan Burkina Faso incorrect format
# nan Burkina Faso incorrect format
# 21800.0 Sao Tome & Principe incorrect format
# 1.2 Sao Tome & Principe incorrect format
# nan Sao Tome & Principe incorrect format
# nan Sao Tome & Principe incorrect format
# 220000.0 Sao Tome & Principe incorrect format
# 5578.0 Sao Tome & Principe incorrect format
# 50.0 Viet Nam incorrect format
# 350.0 Viet Nam incorrect format
# 3.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 0.0 Viet Nam incorrect format
# 70.0 Viet Nam incorrect format
# 20.0 Viet Nam incorrect format
# 0.05 Viet Nam incorrect format
# 1300.0 Viet Nam incorrect format
# 3.0 Viet Nam incorrect format
# 1600.0 Viet Nam incorrect format
# 46.0 Viet Nam incorrect format
# 6.0 Viet Nam incorrect format
# 0.18 Bhutan incorrect format
# 3.301 Solomon Islands incorrect format
# 0.019147 Solomon Islands incorrect format
# 123160.8 Solomon Islands incorrect format
# 200.0 Solomon Islands incorrect format
# 4.0 Solomon Islands incorrect format
# 3.0 Solomon Islands incorrect format
# 215593.0 Barbados incorrect format
# 1.61 Barbados incorrect format
# 766.0 Barbados incorrect format
# nan Barbados incorrect format
# 300.0 Turkey incorrect format
# nan Turkey incorrect format
# 1600.0 Turkey incorrect format
# 8.0 Turkey incorrect format
# nan Turkey incorrect format
# 3487.0 Turkey incorrect format
# nan Turkey incorrect format
# 0.0450161 Vanuatu incorrect format
# 7.2 Tuvalu incorrect format
# 4 communities Tuvalu incorrect format
# 2 financing schemes Tuvalu incorrect format
# 0.027011 Nauru incorrect format
# 0.4 Kiribati incorrect format
# 0.003974 Federated States of Micronesia incorrect format
# 0.05 Federated States of Micronesia incorrect format
# 1.0 Eswatini incorrect format
# 459.0 Eswatini incorrect format
# 0.116 Eswatini incorrect format
# 1.0 Eswatini incorrect format
# 5.0 Eswatini incorrect format
# 5.0 Eswatini incorrect format
# 100.0 Eswatini incorrect format
# 400.0 Eswatini incorrect format
# 0.01 Kosovo incorrect format
# 0.0045 Kosovo incorrect format
# 140'000 Kosovo incorrect format
# nan Kosovo incorrect format
# nan Kosovo incorrect format
# 5250 households  Rwanda incorrect format
# 123 kWh Indonesia incorrect format
# 11 MWp Indonesia incorrect format
# nan Indonesia incorrect format
# nan Indonesia incorrect format
# nan Indonesia incorrect format
# at least $ 13.4 million Indonesia incorrect format
# 241000 of which 66000 women Indonesia incorrect format
# 473.8 ktCO2 Indonesia incorrect format
# nan Indonesia incorrect format
# 77.45 GWh Indonesia incorrect format
# 62.58 ktCO2e Indonesia incorrect format
# 60/140 (w/m) Indonesia incorrect format
# nan Indonesia incorrect format
# 15 MW Indonesia incorrect format
# 8550 MWh Indonesia incorrect format
# US$ 25 million Indonesia incorrect format
# 10 small-medium RE/EE projects Indonesia incorrect format
# 27029 tCO2e Indonesia incorrect format
# nan Indonesia incorrect format
# nan Indonesia incorrect format
# nan Indonesia incorrect format
# nan Indonesia incorrect format
# 1 document Indonesia incorrect format
# nan Indonesia incorrect format
# 40 participants Indonesia incorrect format
# nan Indonesia incorrect format
# 3 sectors
# 4 document Indonesia incorrect format
# nan Indonesia incorrect format
# 4 consultation workshop
# 2 RDF Studies Indonesia incorrect format
# 0.75 Mauritius incorrect format
# nan Mauritius incorrect format
# nan North Macedonia incorrect format
# 291600000.0 North Macedonia incorrect format
# nan North Macedonia incorrect format
# 8.1 North Macedonia incorrect format
# 105.0 North Macedonia incorrect format
# 30390000.0 North Macedonia incorrect format
# 3039000.0 North Macedonia incorrect format
# 20.0 North Macedonia incorrect format
# 20.0 North Macedonia incorrect format
# 7000.0 North Macedonia incorrect format
# 18720000.0 North Macedonia incorrect format
# nan North Macedonia incorrect format
# 2.6 North Macedonia incorrect format
# 6500000.0 North Macedonia incorrect format
# 650.0 North Macedonia incorrect format
# 20.0 North Macedonia incorrect format
# 20.0 North Macedonia incorrect format
# 1000.0 North Macedonia incorrect format
# 195.0 North Macedonia incorrect format
# 100.0 North Macedonia incorrect format
# 65.0 North Macedonia incorrect format
# nan North Macedonia incorrect format
# 0.024 North Macedonia incorrect format
# nan North Macedonia incorrect format
# nan North Macedonia incorrect format
# 245131.0 North Macedonia incorrect format
# 0.05 Cameroon, Republic of incorrect format
# 0.063 Cameroon, Republic of incorrect format
# 0.0022 Cameroon, Republic of incorrect format
# 0.015 Cameroon, Republic of incorrect format
# 1 building Cameroon, Republic of incorrect format
# 2 building Cameroon, Republic of incorrect format
# 1 Lessons learnt and best practice report Namibia incorrect format
# nan Namibia incorrect format
# nan Namibia incorrect format
# 0.0785 Chad incorrect format
# 0.63583 Cambodia incorrect format
# 0.271 Cambodia incorrect format
# 0.048 Cambodia incorrect format
# nan Sudan incorrect format
# nan Sudan incorrect format
# nan Sudan incorrect format
# nan Sudan incorrect format
# nan Kenya incorrect format
# 10000.0 Liberia incorrect format
# nan Liberia incorrect format
# nan Liberia incorrect format
# nan Syria incorrect format
# 125.0 Syria incorrect format
# 24425.0 Syria incorrect format
# 4400.0 Syria incorrect format
# 235000.0 Syria incorrect format
# 54.0 Syria incorrect format
# 18000.0 Syria incorrect format
# 0.0528 Syria incorrect format
# 10000.0 Syria incorrect format
# 10000.0 Syria incorrect format
# 50.0 Syria incorrect format
# 1.0 Syria incorrect format
# 6.0 Syria incorrect format
# 100.0 Syria incorrect format
# 8.0 Syria incorrect format
# 1.0 Syria incorrect format
# 20.0 Syria incorrect format
# 5.0 Syria incorrect format
# 50.0 Syria incorrect format
# 10.0 Syria incorrect format
# 8.0 Syria incorrect format
# 8.0 Syria incorrect format
# 20.0 Syria incorrect format
# 12.0 Syria incorrect format
# 100 Clinics Mozambique incorrect format
#   Mozambique incorrect format
# no HH for Lao PDR
# nan Lao PDR incorrect format
# nan Lao PDR incorrect format
# nan United Republic of Tanzania incorrect format
# Energy Efficiency Strategy Developed United Republic of Tanzania incorrect format
# Energy Efficency Action Plan in place United Republic of Tanzania incorrect format
# MEPS Policy Framework adopted United Republic of Tanzania incorrect format
# A regulatory framework for Energy Efficiency of Large buildings in place United Republic of Tanzania incorrect format
# The methodology to identify classify and notify large energy consumers is in place United Republic of Tanzania incorrect format
# New regulation framework for professional qualifications and certification in energy management and audit adopted United Republic of Tanzania incorrect format
# 1 MW Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# nan Serbia incorrect format
# 2.6 Afghanistan incorrect format
# yes Kyrgyzstan incorrect format
# yes Kyrgyzstan incorrect format
# 3451.0 Prog for Palestinian People incorrect format
# 0.0125 Prog for Palestinian People incorrect format
# 1.0 Prog for Palestinian People incorrect format
# 0.0 Prog for Palestinian People incorrect format
# 413000.0 Prog for Palestinian People incorrect format
# 1.6 Prog for Palestinian People incorrect format
# 2.3 Prog for Palestinian People incorrect format
# nan Prog for Palestinian People incorrect format
# 1500.0 Iraq incorrect format
# 1500.0 Iraq incorrect format
# 1000.0 Iraq incorrect format
# 2800.0 Iraq incorrect format
# nan Iraq incorrect format
# 531628.0 Iraq incorrect format
# 1436292000.0 Iraq incorrect format
# 400.0 Iraq incorrect format
# 4.0 Iraq incorrect format
# nan Iraq incorrect format
# 10.0 Iraq incorrect format
# 55000.0 Iraq incorrect format
# 5.0 Iraq incorrect format
# 120.0 Iraq incorrect format
# 200.0 Iraq incorrect format
# 4449727.0 Iraq incorrect format
# 8.0 Iraq incorrect format
# nan Iraq incorrect format
# 65.0 Iraq incorrect format
# 42.0 Iraq incorrect format
# 17.0 Iraq incorrect format
# 113.0 Iraq incorrect format
# 3001.0 Iraq incorrect format
# 100.0 Iraq incorrect format
# 1000.0 Iraq incorrect format
# 2.0 Iraq incorrect format
# 0.4 Iraq incorrect format
# 10000.0 Iraq incorrect format
# nan Iraq incorrect format
# 14.0 Iraq incorrect format
# 100145.64023481136 Philippines incorrect format
# 0.35 Philippines incorrect format
# nan Philippines incorrect format
# nan Philippines incorrect format
# nan Philippines incorrect format
# 52 buildings India incorrect format
# 330000.0 Mali incorrect format
# 1.0 Mali incorrect format
# 1.0 Mali incorrect format
# 30000.0 Mali incorrect format
# 1.0 Mali incorrect format
# 1000.0 Mali incorrect format
# 1000.0 Mali incorrect format
# 23460.0 Mali incorrect format
# 400.0 Mali incorrect format
# 365.0 Mali incorrect format
# 16929.0 Mali incorrect format
# 8665.0 Mali incorrect format
# 0.3 Mali incorrect format
# nan Mali incorrect format
# nan Mali incorrect format
# 183505.0 Mali incorrect format
# 200.0 Mali incorrect format
# 400.0 Mali incorrect format
# 1.609 Angola incorrect format
# rated “4” (policy/ regulation/strategy adopted but not enforced) Angola incorrect format
# nan Mongolia incorrect format
# 69.0 Mongolia incorrect format
# nan Thailand incorrect format
# 300.0 Thailand incorrect format
# 1.0 Thailand incorrect format
# 1.0 Tajikistan incorrect format
# 50.0 Tajikistan incorrect format
# 1.0 Tajikistan incorrect format
# 1.0 Tajikistan incorrect format
# 2600000.0 Tajikistan incorrect format
# 16000.0 Tajikistan incorrect format
# 0.75 Tajikistan incorrect format
# 100.0 Tajikistan incorrect format
# 17867.0 Tajikistan incorrect format
# 3000000.0 Tajikistan incorrect format
# nan Tajikistan incorrect format
# nan Georgia incorrect format
# 0.196 Georgia incorrect format
# nan Georgia incorrect format
# nan Djibouti incorrect format
# 1. 4 sets              2. 100 participating women.              Djibouti incorrect format
# 2400
# (1200 women) Trinidad & Tobago incorrect format
# 0.108 Trinidad & Tobago incorrect format
# 36
# (12 women) Trinidad & Tobago incorrect format
# nan Trinidad & Tobago incorrect format
# nan Ghana incorrect format
# 0.6 Bangladesh incorrect format
# 2 Policies/regulatory frameworks:               (1) GHG inventory system adopted in Dhaka & Chittagong City
# (2) Dhaka & Chittagong City have formulated investment plans for LCUD investments and measures
#  Bangladesh incorrect format
# 1.57 M Ton CO2eq Bangladesh incorrect format
# 0.0156 M ton of tCO2eq Bangladesh incorrect format
# 0.03 Bangladesh incorrect format
# 0.06 Bangladesh incorrect format
# 0.15 Bangladesh incorrect format
# 0.036 Bangladesh incorrect format
# 1.12 Bangladesh incorrect format
# 0.35 Bangladesh incorrect format
# 1.73 M Ton CO2eq Bangladesh incorrect format
# Policy Recommendation on following 5 points:
# 1.	Climate finance strategy & NDC investment plan
# 2.	Roadmap for Net Zero strategies
# 3.	Scoping study on adopting national circular economy strategy
# 4.	Roadmap on National Hydrogen Stategy
# 5.	Gender responsive NDC implementation plan
#   Bangladesh incorrect format
# nan Bangladesh incorrect format
# nan Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# TBD Myanmar incorrect format
# nan Argentina incorrect format
# nan Argentina incorrect format
# 0.23 Argentina incorrect format
# nan Argentina incorrect format
# 113.0 Argentina incorrect format
# nan Argentina incorrect format
# nan Argentina incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# 30.0 Tunisia incorrect format
# nan Tunisia incorrect format
# 50.0 Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# 50.0 Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Tunisia incorrect format
# nan Kazakhstan incorrect format
# nan Kazakhstan incorrect format
# 2.5 Kazakhstan incorrect format
# 31200000.0 Malaysia incorrect format
# 163000000.0 Malaysia incorrect format
# nan Malaysia incorrect format
# 346442.0 Malaysia incorrect format
# 1.19 Guinea-Bissau incorrect format
# 1500 30% women Montenegro incorrect format
# 10 30% women Montenegro incorrect format
# 1.0 Egypt incorrect format
# 18.0 Egypt incorrect format
# 1.3 Egypt incorrect format
# 1.5 Egypt incorrect format

# %%
outputDfComplete
# Out:
#      Project ID                                              Title  \
# 0      117913.0      Résilience des communautés et des écosystèmes
# 1      117913.0      Résilience des communautés et des écosystèmes
# 2      117913.0      Résilience des communautés et des écosystèmes
# 3      134793.0  Accès aux énergies renouvelables en milieu rur...
# 4      134793.0  Accès aux énergies renouvelables en milieu rur...
# ...         ...                                                ...
# 1174     130610                      Multilateral Support to COP27
# 1175   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1176   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1177   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1178   131201.0                                         Paix Verte
#
#                                         Link       Budget  \
# 0     http://open.undp.org/projects/00117913    3459600.0
# 1     http://open.undp.org/projects/00117913    3459600.0
# 2     http://open.undp.org/projects/00117913    3459600.0
# 3     http://open.undp.org/projects/00134793    1431552.0
# 4     http://open.undp.org/projects/00134793    1431552.0
# ...                                      ...          ...
# 1174                                 Qunatum    1500000.0
# 1175                                     NaN  329490000.0
# 1176                                     NaN  329490000.0
# 1177                                     NaN  329490000.0
# 1178                                     NaN     157000.0
#
#             Beneficiary Category  \
# 0             Electricity Access
# 1                            nan
# 2                            nan
# 3             Electricity Access
# 4                            nan
# ...                          ...
# 1174           Energy (MW added)
# 1175          Electricity Access
# 1176  Capacity Building Training
# 1177                         nan
# 1178               Clean Cooking
#
#                                               Indicator Baseline  Target  \
# 0     Nombre de ménages ayant accès à l’énergie sola...        0  3697.5
# 1     Pourcentage des producteurs de charbon dans le...        0     460
# 2     Pourcentatge des femmes productrices de charbo...        0     460
# 3     Nombre de ménages dans les villages ciblés, y ...        0  6525.0
# 4     Nombre de personnes bénéficiant des services d...    10000   50000
# ...                                                 ...      ...     ...
# 1174  Electricity generation capacity shfited from f...        0     1.5
# 1175  1. Percentage of populations, disaggregated by...      0.0  300000
# 1176  Number of people who benefits from training fo...      NaN    1000
# 1177                                                NaN      NaN     200
# 1178  Nombre d’initiatives d’utilisation des énergie...      0.0  1731.0
#
#                                                   Notes               Donors  \
# 0     Nombre de ménages dirigés par les hommes: 650,...                 UNDP
# 1     Il ya 576 productrices de chanbons qui ont été...                 UNDP
# 2     Il ya 576 productrices de chanbons qui ont été...                 UNDP
# 3     Nombre de ménages dirigés par les hommes: 1200...                 UNDP
# 4                     Environ 50 000 personnes au Total                 UNDP
# ...                                                 ...                  ...
# 1174  The added PV capacities will be mainly impleme...                   EU
# 1175  The objective of PERZI is to create the condit...  Gouvernment, UNDP,
# 1176                                                NaN  Gouvernment, UNDP,
# 1177                                                NaN  Gouvernment, UNDP,
# 1178  The Biogas initiative is a component of the “G...                  PBF
#
#       ...      un-region Region              Economy  LDC SIDS LLDC     HDI  \
# 0     ...  African Group    RBA           Low income  LDC  NaN  NaN     Low
# 1     ...  African Group    RBA           Low income  LDC  NaN  NaN     Low
# 2     ...  African Group    RBA           Low income  LDC  NaN  NaN     Low
# 3     ...  African Group    RBA           Low income  LDC  NaN  NaN     Low
# 4     ...  African Group    RBA           Low income  LDC  NaN  NaN     Low
# ...   ...            ...    ...                  ...  ...  ...  ...     ...
# 1174  ...  African Group   RBAS  Lower middle income  NaN  NaN  NaN    High
# 1175  ...  African Group    RBA  Lower middle income  LDC  NaN  NaN  Medium
# 1176  ...  African Group    RBA  Lower middle income  LDC  NaN  NaN  Medium
# 1177  ...  African Group    RBA  Lower middle income  LDC  NaN  NaN  Medium
# 1178  ...  African Group    RBA  Lower middle income  LDC  NaN  NaN  Medium
#
#       Sahel Direct Conversion Factor Direct Beneficiaries
# 0       NaN                        1               3697.5
# 1       NaN                        0                  0.0
# 2       NaN                        0                  0.0
# 3       NaN                        1               6525.0
# 4       NaN                        0                  0.0
# ...     ...                      ...                  ...
# 1174    NaN                    17500              26250.0
# 1175  Sahel                        1             300000.0
# 1176  Sahel                        0                  0.0
# 1177  Sahel                        0                  0.0
# 1178  Sahel                        1               1731.0
#
# [1179 rows x 37 columns]

# %% [markdown]
# <h4> indirect conversion </h4>

# %%
#open electricity access % data
eAccessDf=pd.read_csv("../01_Input/02_Energy Data/API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_5358776/API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_5358776.csv")
popDf=pd.read_csv("../01_Input/02_Energy Data/API_SP.POP.TOTL_DS2_en_csv_v2_5436324/API_SP.POP.TOTL_DS2_en_csv_v2_5436324.csv")
renewableDf=pd.read_csv("../01_Input/02_Energy Data/API_EG.FEC.RNEW.ZS_DS2_en_csv_v2_5359592/API_EG.FEC.RNEW.ZS_DS2_en_csv_v2_5359592.csv")
cleanDf=pd.read_csv("../01_Input/02_Energy Data/API_EG.CFT.ACCS.ZS_DS2_en_csv_v2_5362815/API_EG.CFT.ACCS.ZS_DS2_en_csv_v2_5362815.csv")

renewableDf=renewableDf.set_index("Country Code")
cleanDf=cleanDf.set_index("Country Code")
eAccessDf=eAccessDf.set_index("Country Code")
popDf=popDf.set_index("Country Code")

# %%
dfList=[]
proportionDict={}
for country in eAccessDf.index:
    
    elAccessPercent=(100-eAccessDf.loc[country]["2020"])/100
    cleanPercent=cleanDf.loc[country]["2020"]/100
    effiPercent=eAccessDf.loc[country]["2020"]/100
    renewPercent=renewableDf.loc[country]["2019"]/100
    
    countryPop=popDf.loc[country]["2020"]
    
    elAccess=elAccessPercent*countryPop
    clean=cleanPercent*countryPop
    effi=effiPercent*countryPop
    renew=renewPercent*countryPop
    
    count=0
    total=0
    
    for val in [elAccess,clean,effi,renew]:
        if not pd.isna(val):
            count+=1
            total+=val
    
    if count>0:
        overall=total/count
    else:
        overall=0
        
    proportionDict[country]={"Electricity access":elAccessPercent,"Clean cooking":cleanPercent,"Energy efficiency":effiPercent,"Renewable energy":renewPercent,"Overall":overall/countryPop}
    dfList.append({"Country Code":country,"Electricity access":elAccess,"Clean cooking":clean,"Energy efficiency":effi,"Renewable energy":renew,"Overall":overall})

indirectPotentials=pd.DataFrame.from_records(dfList)

indirectPotentials.to_csv("../02_Output/03_Countries/indirectPotential.csv")

# %%
# #load Indirect conversion scores
# indirectConversion=pd.read_csv("../01_Input/01_Methodology/Indirect Conversion Factors.csv")
# #load RISE scores
# riseScores=pd.read_excel("../01_Input/02_Energy Data/RISE Scores-2.xlsx")

# def getIndirectBeneficiaries(row):
#     if row["Beneficiary Category"]=="Policy or Regulatory Framework":
#         try:
#             category=row["RISE Taxonomy"]
#         except:###DELETE
#             category="Overall"
        
#         proportion=proportionDict[row["Country Code"]][category]
#         if "Scope" not in row.keys().tolist():#####DELETE
#             row["Scope"]="National"
        
#         if row["Scope"]=="National":
#             potentialPopulation=popDf.loc[row["Country Code"]]["2020"]
#         else:
#             potentialPopulation=row["Policy Population"]
        
#         return potentialPopulation*proportion
        
#     else:
#         return 0
    
# outputDfComplete["Indirect Beneficiaries"]=outputDfComplete.apply(lambda row: getIndirectBeneficiaries(row),axis=1)

# outputDfComplete["Indirect Beneficiaries"] = pd.to_numeric(outputDfComplete["Indirect Beneficiaries"], errors='coerce')

# print(outputDfComplete[outputDfComplete["Beneficiary Category"]=="Policy or Regulatory Framework"])

# %%
##add direct and indirect beneficiaries count to projectDf

projectDf["Direct Beneficiaries"]=projectDf["Project ID"].apply(lambda x: outputDfComplete[outputDfComplete["Project ID"]==x]["Direct Beneficiaries"].sum())

ghgDfComplete=outputDfComplete[outputDfComplete["Beneficiary Category"]=="GHG Emissions Reduction"]

def sumGhg(ghgList,project_id):
    
    ghg=0.0
    for i in ghgList:
        try:
            ghg+=float(i)
        except:
            print(project_id," ghg broken")
    return ghg
    

projectDf["GHG Emissions Reduction"]=projectDf["Project ID"].apply(lambda x: sumGhg(ghgDfComplete[ghgDfComplete["Project ID"]==x]["Target"].tolist(),x))



# projectDf["Indirect Beneficiaries"]=projectDf["Project ID"].apply(lambda x: outputDfComplete[outputDfComplete["Project ID"]==x]["Indirect Beneficiaries"].sum())
# Out:
# 93964.0  ghg broken
# 127444.0  ghg broken
# 117898  ghg broken
# 116395  ghg broken
# 00110796(AC Unit) & 00117012 (PMU)  ghg broken

# %% [markdown]
# <h4> Add energy efficiency (and GHG emissions reduction?) </h4>

# %%
# outputDfComplete["GHG Emissions Reduction"]=outputDfComplete.apply(lambda row: (row["Beneficiary Category"]=="GHG Emissions Reduction")*row["Target"],axis=1)
# # #Energy Saved (MJ)

#####to projects instead now??

# %%
productiveUseCategories=[
    "Agriculture and Food System",
    "Health Services",
    "Education Services",
    "Transportation and E-mobility Services",
    "Water Services",
    "Energy Infrastructure Services",
    "Other Energy Services"
]

# %%
#community centers
#displacement settings

def getBeniCategory(row):
    if row["Beneficiary Category"] in productiveUseCategories+["Electricity Access","Clean Cooking"]:
        outputCategory="Energy Access"
    elif row["Beneficiary Category"] in ["Energy (MW added)","Energy Efficiency Services"]:
        outputCategory="Energy Transition"
    elif row["Beneficiary Category"]=="Policy or Regulatory Framework":
        outputCategory="Policy"
    elif row["Beneficiary Category"]=="GHG Emissions Reduction":
        outputCategory="GHG Emissions Reduction"
    else:
        outputCategory="Other"
    return outputCategory
        
outputDfComplete["Output Category"]=outputDfComplete.apply(lambda row: getBeniCategory(row),axis=1)

# %%
def getBeniSubcategory(row):
    
    if row["Output Category"]=="Energy Transition":
        if row["Beneficiary Category"]=="Energy Efficiency Services":
            beneficiaryCategory="Efficiency"
        elif type(row["Technology"])==str: 
            beneficiaryCategory=row["Technology"]
        else:
            beneficiaryCategory="Transition Missing"    
    elif row["Beneficiary Category"] in productiveUseCategories:
        beneficiaryCategory=row["Beneficiary Category"]##this changes nothing
        
    elif row["Beneficiary Category"] in ["Electricity Access","Energy (MW added)"]:
        beneficiaryCategory="Clean Electricity"
    
    elif row["Beneficiary Category"] =="Clean Cooking":
        beneficiaryCategory="Clean Cooking"

    elif row["Beneficiary Category"]=="Policy or Regulatory Framework":
        try:
            beneficiaryCategory="Policy - "+row["RISE Taxonomy"]
        except:
            beneficiaryCategory="Policy - Other"
        
    else:##need to add finance here
        beneficiaryCategory="Other"
        print(row["Beneficiary Category"])
    return beneficiaryCategory     

        
outputDfComplete["Beneficiary Category Pre"]=outputDfComplete["Beneficiary Category"]
outputDfComplete["Beneficiary Category"]=outputDfComplete.apply(lambda row: getBeniSubcategory(row),axis=1)
# Out:
# nan
# nan
# nan
# Medium Enterprises
# GHG Emissions Reduction
# nan
# GHG Emissions Reduction
# nan
# GHG Emissions Reduction
# GHG Emissions Reduction
# Capacity Building Training
# Capacity Building Training
# nan
# Small Enterprises
# Capacity Building Training
# nan
# Capacity Building Training
# nan
# Capacity Building Training
# Capacity Building Training
# Other
# Entrepreneurship Training
# Entrepreneurship Training
# Capacity Building Training
# GHG Emissions Reduction
# Market Intervention
# Capacity Building Training
# Small Enterprises
# Capacity Building Training
# Entrepreneurship Training
# Entrepreneurship Training
# Capacity Building Training
# GHG Emissions Reduction
# nan
# nan
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Capacity Building Training
# GHG Emissions Reduction
# GHG Emissions Reduction
# nan
# nan
# nan
# nan
# nan
# Campaign Participant
# Capacity Building Training
# Campaign Participant
# Medium Enterprises
# Medium Enterprises
# nan
# GHG Emissions Reduction
# nan
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Medium Enterprises
# Entrepreneurship Training
# Small Enterprises
# nan
# nan
# Other
# Other
# Capacity Building Training
# Capacity Building Training
# nan
# Small Enterprises
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# nan
# Other
# Other
# Other
# Other
# Other
# Capacity Building Training
# Capacity Building Training
# GHG Emissions Reduction
# Capacity Building Training
# Small Enterprises
# Market Intervention
# Small Enterprises
# GHG Emissions Reduction
# nan
# Other
# Other
# Financing support
# Entrepreneurship Training
# Capacity Building Training
# Financing support
# Other
# Other
# Other
# Entrepreneurship Training
# Other
# Other
# Other
# Other
# nan
# nan
# nan
# Small Enterprises
# Medium Enterprises
# Entrepreneurship Training
# Small Enterprises
# nan
# Capacity Building Training
# Capacity Building Training
# Market Intervention
# Market Intervention
# Capacity Building Training
# Capacity Building Training
# nan
# nan
# nan
# nan
# nan
# Capacity Building Training
# Medium Enterprises
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Entrepreneurship Training
# Capacity Building Training
# Health services
# Other
# Other
# Small Enterprises
# nan
# Capacity Building Training
# Campaign Participant
# Capacity Building Training
# Capacity Building Training
# nan
# GHG Emissions Reduction
# GHG Emissions Reduction
# GHG Emissions Reduction
# GHG Emissions Reduction
# Entrepreneurship Training
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Other
# Medium Enterprises
# Capacity Building Training
# Campaign Participant
# Small Enterprises
# Medium Enterprises
# Capacity Building Training
# nan
# nan
# Small Enterprises
# Capacity Building Training
# nan
# GHG Emissions Reduction
# Capacity Building Training
# GHG Emissions Reduction
# Other
# Capacity Building Training
# Medium Enterprises
# Medium Enterprises
# Medium Enterprises
# Small Enterprises
# Capacity Building Training
# Medium Enterprises
# Capacity Building Training
# Campaign Participant
# GHG Emissions Reduction
# nan
# Other
# Capacity Building Training
# Small Enterprises
# GHG Emissions Reduction
# Capacity Building Training
# Medium Enterprises
# Entrepreneurship Training
# Small Enterprises
# GHG Emissions Reduction
# Medium Enterprises
# Small Enterprises
# Campaign Participant
# nan
# Capacity Building Training
# GHG Emissions Reduction
# GHG Emissions Reduction
# Other
# nan
# Small Enterprises
# GHG Emissions Reduction
# GHG Emissions Reduction
# Other
# Capacity Building Training
# Small Enterprises
# nan
# nan
# Small Enterprises
# Small Enterprises
# GHG Emissions Reduction
# nan
# nan
# nan
# nan
# nan
# Capacity Building Training
# Electricity Access / Energy (MW added)
# Capacity Building Training
# Financing support
# Capacity Building Training
# Financing support
# Capacity Building Training
# Financing support
# Capacity Building Training
# Campaign Participant
# nan
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Campaign Participant
# nan
# Capacity Building Training
# Medium Enterprises
# Entrepreneurship Training
# Campaign Participant
# Energy infrastructure services
# Capacity Building Training
# Medium Enterprises
# Campaign Participant
# Small Enterprises
# Other
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Financing support
# Other
# nan
# Medium Enterprises
# Other
# Capacity Building Training
# nan
# Market Intervention
# Small Enterprises
# Other
# nan
# Capacity Building Training
# nan
# nan
# Other
# nan
# Campaign Participant
# nan
# nan
# Campaign Participant
# GHG Emissions Reduction
# Energy Storage (MW)
# Medium Enterprises
# Small Enterprises
# Small Enterprises
# Capacity Building Training
# Campaign Participant
# Medium Enterprises
# nan
# Medium Enterprises
# Market Intervention
# Market Intervention
# Capacity Building Training
# Capacity Building Training
# Campaign Participant
# nan
# Market Intervention
# Other
# Capacity Building Training
# Capacity Building Training
# Campaign Participant
# Market Intervention
# Market Intervention
# Market Intervention
# nan
# Market Intervention
# Capacity Building Training
# Entrepreneurship Training
# Capacity Building Training
# Capacity Building Training
# Small Enterprises
# nan
# nan
# Entrepreneurship Training
# Capacity Building Training
# Medium Enterprises
# Capacity Building Training
# Medium Enterprises
# Capacity Building Training
# Campaign Participant
# Energy access
# water services
# Capacity Building Training
# Other
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Campaign Participant
# GHG Emissions Reduction
# nan
# nan
# Capacity Building Training
# nan
# nan
# Entrepreneurship Training
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Capacity Building Training
# Capacity Training
# Energy Access - disaster affected communities -
# Energy Access - disaster affected communities -
# Energy Access
# nan
# Entrepreneurship Training
# Capacity Building Training
# Small Enterprises
# nan
# nan
# nan
# Capacity Building Training
# GHG Emissions Reduction
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Medium Enterprises
# Energy Transition
# Capacity Building Training
# Other
# nan
# Campaign Participant
# GHG Emissions Reduction
# Small Enterprises
# Campaign Participant
# Campaign Participant
# Capacity Building Training
# Capacity Building Training
# nan
# nan
# Other
# Market Intervention
# GHG Emissions Reduction
# nan
# nan
# Medium Enterprises
# nan
# nan
# nan
# nan
# nan
# Capacity Building Training
# Small Enterprises
# Capacity Building Training
# Entrepreneurship Training
# GHG Emissions Reduction
# Medium Enterprises
# Small Enterprises
# Capacity Building Training
# GHG Emissions Reduction
# nan
# Capacity Building Training
# Capacity Building Training
# GHG Emissions Reduction
# nan
# nan
# GHG Emissions Reduction
# Households and Women, Policy and Regulatory Framework
# Capacity Building Training
# nan
# GHG Emissions Reduction
# Capacity Building Training
# Market Intervention
# Medium Enterprises
# Campaign Participant
# Capacity Building Training
# GHG Emissions Reduction
# Capacity Building Training
# Capacity Building Training
# GHG Emissions Reduction
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Capacity Building Training
# Campaign Participant
# GHG Emissions Reduction
# Artisanal Palm Oil Producers
# General Public
# Electric Vehicle Businesses
# GHG Emissions Reduction
# GHG Emissions Reduction
# Capacity Building Training
# GHG Emissions Reduction
# Small Enterprises
# Capacity Building Training
# GHG Emissions Reduction
# Other energy services
# Small Enterprises
# Capacity Building Training
# Entrepreneurship Training
# Campaign Participant
# nan
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Capacity Building Training
# Capacity Building Training
# nan
# Campaign Participant
# Capacity Building Training
# Capacity Building Training
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Capacity Building Training
# Small Enterprises
# GHG Emissions Reduction
# nan
# Medium Enterprises
# Campaign Participant
# Capacity Building Training
# Small Enterprises
# Capacity Building Training
# Market Intervention
# Market Intervention
# GHG Emissions Reduction
# GHG Emissions Reduction
# nan
# nan
# nan
# nan
# Capacity Building Training
# nan

# %% [markdown]
# <h1> Update outputs, projects, donors, and country data with api, pims, and summary stats </h1>

# %% [markdown]
# <h3>download portfolio data from API</h3>

# %%
#should refactor this so there is a single retreival of country metadata
allCountryCodes=pd.read_csv("../01_Input/03_Country Meta/country-iso.csv")["alpha-3"].unique().tolist()
unregions=pd.read_csv("../02_Output/03_Countries/countryMetadata.csv").set_index("Country Code")
bureaus=pd.read_csv("../01_Input/03_Country Meta/country-iso.csv").set_index("alpha-3")

# %%
def nameToIsoGlobal(countryName):
    iso=countrynames.to_code_3(countryName, fuzzy=True)
    if iso==None:
        iso="NA"
    return iso

# %%
solutionsDict={"Others":7,
"Enhance national prevention and recovery capacities for resilient societies":3,
"Promote nature-based solutions for a sustainable planet":4,
"Keeping people out of poverty":1,
"Close the energy gap":5,
"Strengthen gender equality and the empowerment of women and girls":6,
"Strenghten gender equality and the empowerment of women and girls":6,
              "Strengthen effective, inclusive and accountable governance":2}

# %%
#test
# j = pd.read_json('https://api.open.undp.org/api/project_list/?year={}&operating_unit={}'.format("2022","TUV"))
# for d in j.data.data:
#     print(d)

# %%
def downloadFullPortfolio():

    #fundingCategories=pd.read_csv("../../SIDS-Data-Platform-API/api/data/portfolio/fundingCategories.csv",encoding="utf-8")
    #fundingCategories=fundingCategories.set_index('donor')

    df = pd.DataFrame()

    rows=[]


    for country in allCountryCodes:
        print(country)
        for yr in range(2010,2023):
            j = pd.read_json('https://api.open.undp.org/api/project_list/?year={}&operating_unit={}'.format(yr,country))
            for d in j.data.data:
                #print(d)
                try:
                    sdg = [int(s['id']) for s in d['sdg']]
                except:
                    sdg = None
                try:
                    solution = [s['name'] for s in d['signature_solution']]
                except:
                    solution = None

                title=d['title']

                donors= d['donor']
                
                unregion=unregions.loc["AFG"]["un-region"]
                bureau=bureaus.loc["AFG"]["undp-region"]

                line = {'Project ID':d['project_id'],
                        'country_atlas':country,
                        'un-region':unregion,
                        'bureau':bureau,
                        'year':yr,
                        'title_atlas':d['title'],
                        'description':d['description'],
                        'sector':d['sector'],
                        'budget_atlas':d['budget'],
                        'expense':d['expense'],
                        'sdgs':sdg,
                        'solution':solution,
                        'donors_atlas':donors
                       }

                #l = pd.DataFrame(line)

                rows.append(line)

    df=pd.DataFrame.from_records(rows)        

    return df

# %%
# fullAtlasPortfolio=downloadFullPortfolio()
# fullAtlasPortfolio.to_csv('../02_Output/01_Projects/allAtlasData.csv',ignore_index=True, encoding="utf-8")

# %%
#filter projects based on if energy is included in title, description, sector, sdg7, solution 5

newProjects=[]

keywords=["Energy","Electric","Électrique", "Eléctric","Fuel","Clean Cooking", "Energia","Energie","Grid","Renewable"]

df=pd.read_csv('../02_Output/01_Projects/allAtlasData.csv')


df.rename(columns={'donors': 'donors_atlas', 'id': 'Project ID'}, inplace=True)

print(df)
for index,row in df.iterrows():

    if '7' in row['sdgs'].strip('][').split(', ') or 'Close the energy gap' in row['solution'] or any(sub.lower() in row['title'].lower() for sub in keywords) or any(sub.lower() in row['description'].lower() for sub in keywords):
        source="Non-VF"
        for donor in ast.literal_eval(row['donors_atlas']):#.strip('][').split(', '):
            try:
                if fundingJson[donor]['category']=="Vertical Funds":
                    source="VF"
            except:
                pass#print(donor)
        row["funding source"]=source
    
        lifetimeBudget=df[df["Project ID"]==row["Project ID"]]["budget"].sum()
        row["lifetime budget"]=lifetimeBudget
        
        
        newProjects.append(row)
        
        
dfFiltered=pd.DataFrame.from_records(newProjects)

dfFiltered.to_csv('../02_Output/01_Projects/atlasEnergyPortfolio.csv')




##2022 total of 570M
# Out:
#        Project ID country           un-region bureau  year  \
# 0           61104     AFG  Asia-Pacific Group   RBAP  2012
# 1           57359     AFG  Asia-Pacific Group   RBAP  2012
# 2           60777     AFG  Asia-Pacific Group   RBAP  2012
# 3           58922     AFG  Asia-Pacific Group   RBAP  2012
# 4           47111     AFG  Asia-Pacific Group   RBAP  2012
# ...           ...     ...                 ...    ...   ...
# 50056      119624     ZWE  Asia-Pacific Group   RBAP  2022
# 50057      118587     ZWE  Asia-Pacific Group   RBAP  2022
# 50058      108414     ZWE  Asia-Pacific Group   RBAP  2022
# 50059       96722     ZWE  Asia-Pacific Group   RBAP  2022
# 50060       96886     ZWE  Asia-Pacific Group   RBAP  2022
#
#                                                    title  \
# 0      Law and Order Trust Fund for Afghanistan – Pha...
# 1      National Area-Based Development Programme Phas...
# 2            Afghanistan Peace & Reintegration Programme
# 3       Afghanistan Sub-National Governance Programme II
# 4                     Making Budgets and Aid Work (MBAW)
# ...                                                  ...
# 50056                             Youth Connekt Zimbabwe
# 50057  Building Trust and Confidence in Zimbabwes Tra...
# 50058             Support Services to Ministry of Health
# 50059         Improved Human Rights Delivery 2016 - 2020
# 50060         Pro-Poor Implementation and SDGs 2016-2020
#
#                                              description  \
# 0      Law and Order Trust Fund for Afghanistan – Pha...
# 1      National Area Based Development Programme - Ph...
# 2      Afghanistan Peace & Reintegration Programme wo...
# 3      Afghanistan Sub-National Governance Programme ...
# 4      Making Budgets and Aid Work (MBAW) supports Mi...
# ...                                                  ...
# 50056  This project seeks to empower youth in the imp...
# 50057  This project seeks to contribute towards build...
# 50058  Support to the implementation of the TB and Ma...
# 50059  Overriding objective of the new programme is t...
# 50060  It aims to strengthen government efforts in th...
#
#                                                   sector     budget  \
# 0              [{'code': '3', 'name': 'Basic Services'}]  613373891
# 1      [{'code': '17', 'name': 'Eradicate poverty in ...   71978747
# 2      [{'code': '19', 'name': 'Build resilience to s...   54304322
# 3      [{'code': '17', 'name': 'Eradicate poverty in ...   26515496
# 4      [{'code': '3', 'name': 'Basic Services'}, {'co...   10400001
# ...                                                  ...        ...
# 50056  [{'code': '17', 'name': 'Eradicate poverty in ...      11212
# 50057  [{'code': '19', 'name': 'Build resilience to s...       6508
# 50058  [{'code': '17', 'name': 'Eradicate poverty in ...       4558
# 50059  [{'code': '18', 'name': 'Accelerate structural...       1352
# 50060  [{'code': '1', 'name': 'Inclusive Growth'}, {'...          1
#
#          expense         sdgs  \
# 0      493403788         [16]
# 1       44918385      [1, 16]
# 2       34390236         [16]
# 3       17026503      [1, 17]
# 4        6048847         [16]
# ...          ...          ...
# 50056     163383      [1, 10]
# 50057       6492         [16]
# 50058    1017567   [1, 17, 3]
# 50059       1283         [16]
# 50060      12159  [1, 10, 17]
#
#                                                 solution  \
# 0                                             ['Others']
# 1                      ['Keeping people out of poverty']
# 2      ['Others', 'Strengthen effective, inclusive an...
# 3            ['Others', 'Keeping people out of poverty']
# 4                                             ['Others']
# ...                                                  ...
# 50056                                         ['Others']
# 50057                                         ['Others']
# 50058        ['Others', 'Keeping people out of poverty']
# 50059                                         ['Others']
# 50060                                         ['Others']
#
#                                             donors_atlas
# 0      ['DEPARTMENT FOR INTERNATIONAL DEVELOPMENT (DF...
# 1      ['AGENCIA ESPANOLA DE COOPERACION INTERNACIONA...
# 2      ['AGENCIA ESPANOLA DE COOPERACION INTERNACIONA...
# 3      ['Australian Agency for International Developm...
# 4      ['CANADIAN INTERNATIONAL DEVELOPMENT AGENCY', ...
# ...                                                  ...
# 50056                 ['UNITED NATIONS DEVELOPMENT PRO']
# 50057  ['Peacebuilding Fund', 'UNITED NATIONS DEVELOP...
# 50058  ['GLOBAL FUND TO FIGHT AIDS, TUBERCULOSIS', 'G...
# 50059  ['COL-ALCALDIA DE QUIBDO', 'GOVERNMENT OF JAPA...
# 50060  ['FOOD AND AGRICULTURE ORGANIZATION OF THE UNI...
#
# [50061 rows x 13 columns]

# %% [markdown]
# <h4> add atlas and pims metadata to project df </h4>

# %%
#ATLAS api to get project metadata


##note during refactor, replace this import with the file directly updated including api results
atlasData=pd.read_csv("../02_Output/01_Projects/atlasEnergyPortfolio.csv",usecols=["Project ID","sdgs","solution","description","donors_atlas"])

print(atlasData)
#this should pull disaggregated donor funding from api

projectDf=pd.merge(projectDf,atlasData,on="Project ID",how="left").drop_duplicates(subset='Project ID')

projectDf["Donors"]= projectDf['donors_atlas'].combine_first(projectDf['Donors'])

projectDf=projectDf.drop(columns=["donors_atlas"])

projectDf.to_csv("../02_Output/01_Projects/projectDfFull.csv")

projectDf
# Out:
#       Project ID                                        description  \
# 0          88841  Economic growth is accelerated to reduce vulne...
# 1          88841  Economic growth is accelerated to reduce vulne...
# 2          93793  National Human Development Report Extractive I...
# 3          88841  Economic growth is accelerated to reduce vulne...
# 4          94515  Support Afghanistan Livelihoods and Mobility (...
# ...          ...                                                ...
# 3620      133885  Towards Ending AIDS as a Public Health Threat ...
# 3621      143014  Supporting the implementation of Low Emissions...
# 3622      118606  Conversion from HFC-134a to isobutane in the m...
# 3623      137178  Reduction of HCFC-22 through the adoption of e...
# 3624       95621  Climate change mitigation and adaptation scale...
#
#                sdgs                                     solution  \
# 0            [1, 7]  ['Others', 'Keeping people out of poverty']
# 1            [1, 7]  ['Others', 'Keeping people out of poverty']
# 2         [1, 2, 7]                                   ['Others']
# 3            [1, 7]  ['Others', 'Keeping people out of poverty']
# 4      [1, 7, 8, 9]           ['Others', 'Close the energy gap']
# ...             ...                                          ...
# 3620     [17, 3, 7]                                   ['Others']
# 3621  [1, 13, 7, 9]                                   ['Others']
# 3622         [7, 9]                                   ['Others']
# 3623     [12, 7, 9]                                   ['Others']
# 3624     [1, 13, 7]                                   ['Others']
#
#                                            donors_atlas
# 0     ['GOVERNMENT OF REPUBLIC OF KOREA', 'UNITED NA...
# 1     ['GOVERNMENT OF REPUBLIC OF KOREA', 'UNITED NA...
# 2                    ['UNITED NATIONS DEVELOPMENT PRO']
# 3     ['GOVERNMENT OF REPUBLIC OF KOREA', 'UNITED NA...
# 4     ['GOVERNMENT OF FINLAND', 'UNITED NATIONS DEVE...
# ...                                                 ...
# 3620  ['GLOBAL FUND TO FIGHT AIDS, TUBERCULOSIS', 'U...
# 3621  ['Adam Smith International', 'FEDERAL MINISTRY...
# 3622  ['FRENCH DEVELOPMENT AGENCY', 'MONTREAL PROTOC...
# 3623                              ['MONTREAL PROTOCOL']
# 3624  ['GOVERNMENT OF RUSSIAN FEDERATION', 'SWEDISH ...
#
# [3625 rows x 5 columns]
#     Project ID                                      Project Title  \
# 0     117913.0      Résilience des communautés et des écosystèmes
# 4     134793.0  Accès aux énergies renouvelables en milieu rur...
# 6    1002293.0  Projet de développement des terroirs villageoi...
# 7      91204.0   Apoyo a la Modernización de La Gestión Ambiental
# 8     133871.0                     Beyond Recovery COVID19 Energy
# ..         ...                                                ...
# 596       4998      Grid-connected Small-Scale Photovoltaic Syste
# 597     130275                    Promote small-scale PV-UNDP-EGY
# 598     130610                      Multilateral Support to COP27
# 599   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 600   131201.0                                         Paix Verte
#
#           Budget     Country Country Code  \
# 0      3459600.0        Togo          TGO
# 4      1431552.0        Togo          TGO
# 6            NaN        Togo          TGO
# 7      4202031.0      Panama          PAN
# 8       473000.0      Panama          PAN
# ..           ...         ...          ...
# 596    3536364.0       Egypt          EGY
# 597    1103288.0       Egypt          EGY
# 598    1500000.0       Egypt          EGY
# 599  329490000.0  Mauritania          MRT
# 600     157000.0  Mauritania          MRT
#
#                                                   Link  \
# 0               http://open.undp.org/projects/00117913
# 4               http://open.undp.org/projects/00134793
# 6               http://open.undp.org/projects/01002293
# 7              https://open.undp.org/projects/00082182
# 8    https://www.undp.org/es/panama/noticias/dos-ag...
# ..                                                 ...
# 596                                              PIMS+
# 597                                           Quantum
# 598                                            Qunatum
# 599                                                NaN
# 600                                                NaN
#
#                                                 Donors VF or Non-VF  \
# 0                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# 4                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# 6                                                 UNDP       Non-VF
# 7    UNDP (TRAC 4000) CLIMATE PROMISE (28708) - NDC...       Non-VF
# 8                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# ..                                                 ...          ...
# 596                                                GEF           VF
# 597                                              Japan       Non-VF
# 598                                                 EU       Non-VF
# 599                                Gouvernment, UNDP,        Non-VF
# 600                                                PBF       Non-VF
#
#      Output Count  Direct Beneficiaries  GHG Emissions Reduction  \
# 0               3                3697.5                      0.0
# 4               3                6525.0                      0.0
# 6               1                 350.0                      0.0
# 7               1                   0.0                      0.0
# 8               2               17500.0                      0.0
# ..            ...                   ...                      ...
# 596             1              315000.0                      0.0
# 597             1               22750.0                      0.0
# 598             1               26250.0                      0.0
# 599             3              300000.0                      0.0
# 600             1                1731.0                      0.0
#
#                                            description       sdgs  \
# 0    Il s’agit de la promotion du développement Loc...       [13]
# 4    Accélération de l’accès aux énergies renouvela...        [7]
# 6                                                  NaN        NaN
# 7                                                  NaN        NaN
# 8    Acceso universal, a través de la implementació...  [1, 5, 9]
# ..                                                 ...        ...
# 596                                                NaN        NaN
# 597                                                NaN        NaN
# 598                                                NaN        NaN
# 599                                                NaN        NaN
# 600                                                NaN        NaN
#
#                                               solution
# 0                   ['Others', 'Close the energy gap']
# 4                             ['Close the energy gap']
# 6                                                  NaN
# 7                                                  NaN
# 8    ['Promote nature-based solutions for a sustain...
# ..                                                 ...
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
# 600                                                NaN
#
# [392 rows x 14 columns]

# %%
#PIMS export to get project metadata
pimsData=pd.read_excel("../01_Input/05_PIMS/pims-2-16.xlsx")

pimsDes={}

for index,project in pimsData.iterrows():
    if project["Project ID"] in projectDf["Project ID"].tolist():
        if not pd.isna(project["Project Description"]):
            pimsDes[project["Project ID"]]=project["Project Description"]

def addPimsDes(projectId,description):
    if pd.isna(description):
        if projectId in pimsDes:
            return pimsDes[projectId]
    
    return description

# %%
projectDf["description"]=projectDf.apply(lambda row: addPimsDes(row["Project ID"],row["description"]),axis=1)

print(projectDf["description"])
# Out:
# 0      Il s’agit de la promotion du développement Loc...
# 4      Accélération de l’accès aux énergies renouvela...
# 6                                                    NaN
# 7                                                    NaN
# 8      Acceso universal, a través de la implementació...
#                              ...
# 596                                                  NaN
# 597                                                  NaN
# 598                                                  NaN
# 599                                                  NaN
# 600                                                  NaN
# Name: description, Length: 392, dtype: object

# %% [markdown]
# <h3> gender markers </h3>

# %%
gender_df=pd.read_excel("../01_Input/06_Gender/GM SS4 SS5 14Jan2024.xlsx")
gender_dict=dict(zip(gender_df['Project Number'], gender_df['Marker Text']))
print(gender_dict)
# Out:
# {96168: 'GEN2', 101293: 'GEN1', 102775: 'GEN2', 104400: 'GEN2', 110941: 'GEN2', 1000573: 'GEN2', 96606: 'GEN2', 108253: 'GEN2', 120509: 'GEN2', 134230: 'GEN2', 112311: 'GEN2', 112042: 'GEN2', 101356: 'GEN2', 103304: 'GEN2', 107047: 'GEN2', 1000553: 'GEN3', 108562: 'GEN2', 97828: 'GEN2', 1000372: 'GEN1', 112296: 'GEN1', 129287: 'GEN2', 1000444: 'GEN0', 54966: 'GEN2', 101711: 'GEN2', 123413: 'GEN2', 131509: 'GEN2', 130986: 'GEN1', 119240: 'GEN1', 130577: 'GEN1', 131175: 'GEN2', 96384: 'GEN2', 96410: 'GEN3', 107983: 'GEN3', 128847: 'GEN2', 131157: 'GEN1', 96170: 'GEN2', 113742: 'GEN2', 113743: 'GEN2', 115515: 'GEN2', 122351: 'GEN2', 132452: 'GEN2', 90309: 'GEN2', 98124: 'GEN2', 98222: 'GEN2', 98610: 'GEN2', 131546: 'GEN2', 106888: 'GEN3', 112399: 'GEN2', 118332: 'GEN2', 126347: 'GEN2', 130650: 'GEN2', 1000318: 'GEN2', 99740: 'GEN1', 131307: 'GEN2', 92275: 'GEN2', 94434: 'GEN3', 103905: 'GEN0', 104433: 'GEN2', 113647: 'GEN2', 114327: 'GEN2', 121017: 'GEN2', 123359: 'GEN2', 130941: 'GEN2', 131523: 'GEN1', 93799: 'GEN0', 104532: 'GEN2', 107410: 'GEN2', 132912: 'GEN2', 124391: 'GEN2', 90324: 'GEN2', 118606: 'GEN2', 82850: 'GEN1', 105643: 'GEN2', 116770: 'GEN2', 93439: 'GEN2', 115959: 'GEN2', 104683: 'GEN2', 122689: 'GEN1', 109047: 'GEN1', 110089: 'GEN1', 117650: 'GEN2', 87718: 'GEN2', 100826: 'GEN2', 116382: 'GEN2', 122284: 'GEN2', 133343: 'GEN2', 134066: 'GEN2', 108943: 'GEN0', 132664: 'GEN2', 40112: 'GEN3', 115517: 'GEN2', 130293: 'GEN2', 102170: 'GEN2', 120993: 'GEN2', 127200: 'GEN2', 133363: 'GEN2', 133455: 'GEN2', 126989: 'GEN2', 91460: 'GEN2', 128865: 'GEN2', 96531: 'GEN1', 119898: 'GEN1', 122433: 'GEN2', 129366: 'GEN2', 101330: 'GEN1', 130352: 'GEN2', 132364: 'GEN2', 98433: 'GEN2', 104152: 'GEN2', 122883: 'GEN2', 108188: 'GEN2', 120894: 'GEN2', 126056: 'GEN3', 126065: 'GEN1', 124165: 'GEN2', 103218: 'GEN2', 103502: 'GEN1', 116081: 'GEN1', 1000271: 'GEN2', 129151: 'GEN2', 104333: 'GEN1', 113495: 'GEN1', 115246: 'GEN1', 120304: 'GEN2', 127321: 'GEN2', 130776: 'GEN1', 106044: 'GEN1', 119775: 'GEN2', 119776: 'GEN2', 119778: 'GEN2', 125011: 'GEN1', 104559: 'GEN2', 110601: 'GEN2', 117173: 'GEN2', 121535: 'GEN2', 134334: 'GEN2', 1000872: 'GEN2', 101455: 'GEN2', 106918: 'GEN2', 115912: 'GEN2', 96848: 'GEN2', 107041: 'GEN2', 123540: 'GEN1', 132200: 'GEN2', 105641: 'GEN2', 109722: 'GEN2', 126471: 'GEN3', 129031: 'GEN2', 129076: 'GEN1', 126406: 'GEN1', 93047: 'GEN2', 119970: 'GEN2', 122656: 'GEN2', 126498: 'GEN2', 118271: 'GEN1', 118943: 'GEN2', 94537: 'GEN2', 116208: 'GEN1', 125719: 'GEN2', 114791: 'GEN2', 116611: 'GEN1', 130229: 'GEN1', 130681: 'GEN1', 104689: 'GEN1', 126443: 'GEN2', 131273: 'GEN2', 115034: 'GEN3', 126295: 'GEN2', 105852: 'GEN2', 128730: 'GEN2', 130655: 'GEN2', 1000604: 'GEN2', 131645: 'GEN2', 122633: 'GEN2', 108967: 'GEN1', 128706: 'GEN2', 95939: 'GEN1', 95942: 'GEN2', 101497: 'GEN2', 120859: 'GEN2', 128243: 'GEN1', 129944: 'GEN1', 130361: 'GEN1', 97049: 'GEN2', 100758: 'GEN2', 103399: 'GEN2', 105972: 'GEN2', 115472: 'GEN1', 116726: 'GEN1', 126622: 'GEN2', 131695: 'GEN2', 95405: 'GEN1', 122538: 'GEN2', 1001496: 'GEN1', 90382: 'GEN2', 110414: 'GEN2', 116676: 'GEN2', 116678: 'GEN2', 108732: 'GEN2', 115115: 'GEN1', 119237: 'GEN2', 126590: 'GEN2', 1000365: 'GEN2', 1000843: 'GEN2', 115239: 'GEN2', 130659: 'GEN1', 116870: 'GEN1', 119355: 'GEN2', 127520: 'GEN1', 127524: 'GEN1', 107558: 'GEN2', 115360: 'GEN1', 125236: 'GEN2', 126261: 'GEN2', 122732: 'GEN2', 125405: 'GEN2', 115686: 'GEN1', 104558: 'GEN3', 1000376: 'GEN2', 120795: 'GEN2', 94274: 'GEN1', 91748: 'GEN2', 120837: 'GEN2', 126333: 'GEN2', 116841: 'GEN2', 120971: 'GEN2', 116271: 'GEN1', 131620: 'GEN1', 1000727: 'GEN2', 1000781: 'GEN2', 1000952: 'GEN2', 126494: 'GEN1', 132255: 'GEN2', 132580: 'GEN2', 125314: 'GEN1', 132380: 'GEN1', 132948: 'GEN0', 1000283: 'GEN3', 1000284: 'GEN2', 133952: 'GEN1', 1000825: 'GEN2', 116825: 'GEN1', 126385: 'GEN3', 126386: 'GEN3', 126387: 'GEN3', 132179: 'GEN1', 122575: 'GEN2', 121090: 'GEN1', 123916: 'GEN2', 122887: 'GEN1', 126148: 'GEN2' ...

# %%
def get_gender_marker(projectId):
    try:
        projectId=int(projectId)
        if projectId in gender_dict:
            print("success")
            return(gender_dict[projectId])
        else:
            return "Missing"
    except:
        return "Missing project id"

# %%
projectDf["Gender Marker"]=projectDf["Project ID"].apply(lambda x: get_gender_marker(x))
# Out:
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success

# %%
print(projectDf)
# Out:
#     Project ID                                      Project Title  \
# 0     117913.0      Résilience des communautés et des écosystèmes
# 4     134793.0  Accès aux énergies renouvelables en milieu rur...
# 6    1002293.0  Projet de développement des terroirs villageoi...
# 7      91204.0   Apoyo a la Modernización de La Gestión Ambiental
# 8     133871.0                     Beyond Recovery COVID19 Energy
# ..         ...                                                ...
# 596       4998      Grid-connected Small-Scale Photovoltaic Syste
# 597     130275                    Promote small-scale PV-UNDP-EGY
# 598     130610                      Multilateral Support to COP27
# 599   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 600   131201.0                                         Paix Verte
#
#           Budget     Country Country Code  \
# 0      3459600.0        Togo          TGO
# 4      1431552.0        Togo          TGO
# 6            NaN        Togo          TGO
# 7      4202031.0      Panama          PAN
# 8       473000.0      Panama          PAN
# ..           ...         ...          ...
# 596    3536364.0       Egypt          EGY
# 597    1103288.0       Egypt          EGY
# 598    1500000.0       Egypt          EGY
# 599  329490000.0  Mauritania          MRT
# 600     157000.0  Mauritania          MRT
#
#                                                   Link  \
# 0               http://open.undp.org/projects/00117913
# 4               http://open.undp.org/projects/00134793
# 6               http://open.undp.org/projects/01002293
# 7              https://open.undp.org/projects/00082182
# 8    https://www.undp.org/es/panama/noticias/dos-ag...
# ..                                                 ...
# 596                                              PIMS+
# 597                                           Quantum
# 598                                            Qunatum
# 599                                                NaN
# 600                                                NaN
#
#                                                 Donors VF or Non-VF  \
# 0                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# 4                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# 6                                                 UNDP       Non-VF
# 7    UNDP (TRAC 4000) CLIMATE PROMISE (28708) - NDC...       Non-VF
# 8                   ['UNITED NATIONS DEVELOPMENT PRO']       Non-VF
# ..                                                 ...          ...
# 596                                                GEF           VF
# 597                                              Japan       Non-VF
# 598                                                 EU       Non-VF
# 599                                Gouvernment, UNDP,        Non-VF
# 600                                                PBF       Non-VF
#
#      Output Count  Direct Beneficiaries  GHG Emissions Reduction  \
# 0               3                3697.5                      0.0
# 4               3                6525.0                      0.0
# 6               1                 350.0                      0.0
# 7               1                   0.0                      0.0
# 8               2               17500.0                      0.0
# ..            ...                   ...                      ...
# 596             1              315000.0                      0.0
# 597             1               22750.0                      0.0
# 598             1               26250.0                      0.0
# 599             3              300000.0                      0.0
# 600             1                1731.0                      0.0
#
#                                            description       sdgs  \
# 0    Il s’agit de la promotion du développement Loc...       [13]
# 4    Accélération de l’accès aux énergies renouvela...        [7]
# 6                                                  NaN        NaN
# 7                                                  NaN        NaN
# 8    Acceso universal, a través de la implementació...  [1, 5, 9]
# ..                                                 ...        ...
# 596                                                NaN        NaN
# 597                                                NaN        NaN
# 598                                                NaN        NaN
# 599                                                NaN        NaN
# 600                                                NaN        NaN
#
#                                               solution Gender Marker
# 0                   ['Others', 'Close the energy gap']       Missing
# 4                             ['Close the energy gap']       Missing
# 6                                                  NaN       Missing
# 7                                                  NaN       Missing
# 8    ['Promote nature-based solutions for a sustain...       Missing
# ..                                                 ...           ...
# 596                                                NaN       Missing
# 597                                                NaN          GEN2
# 598                                                NaN          GEN2
# 599                                                NaN          GEN2
# 600                                                NaN       Missing
#
# [392 rows x 15 columns]

# %% [markdown]
# <h3>Update countryMetadata and donorDf</h3>

# %% [markdown]
# <h4> Extract donor df </h4>

# %%
#analyze data from project list
print(projectDf["Donors"].unique().tolist())


#donorList

#get total projects

#add metadata from manual categories
# Out:
# ["['UNITED NATIONS DEVELOPMENT PRO']", 'UNDP', 'UNDP (TRAC 4000) CLIMATE PROMISE (28708) - NDC Partnership (PAF)\nAes Panamá S.R.L\nFederal Ministry For The Environment, Nature Conservation And Nuclear Safety\nPan-Government', 'GEF', nan, 'UNDP, UNICEF, UNFPA, UNCDF, RCO, UNDSS, UNCTAD, DCO.', 'Department of Energy. South Africa', 'UNDP LVGA', 'Japan', 'Government of Japan', "['Aver, Inc. S.A.L', 'Beesline International SAL', 'Biomass S. A. L.', 'ELCIR S.A.L', 'EUROPEAN COMMISSION', 'KREDITANSTALT FUR WIEDERAUFBAU', 'MINISTRY OF FOREIGN AFFAIRS, NORWAY', 'Petco s.a.l', 'Roky Plast SAL', 'UNITED NATIONS DEVELOPMENT PRO']", 'KfW', 'EU', '', 'Government of Italy ', "['Generic foundation donor code', 'MPTF-Supporting Resilient Livelihoods and Food Security in Yemen JP (ERRY II )', 'UNITED NATIONS DEVELOPMENT PRO']", "['Generic foundation donor code', 'MPTFO-JP Yemen ERRY III', 'UNITED NATIONS DEVELOPMENT PRO']", "['Kuwait Fund for Arab Economic Development']", "['EUROPEAN COMMISSION']", 'FCDO, GAC', 'GF', "['Operador Nacional de Electricidad - CENACE']", 'Climate Promise, BMZ', "Donor 00012: UNDP's Rapid Response Facility (RRF2) program https://www.undp.org/press-releases/covid-19-30-million-rapid-response-facility-launched-vulnerable-countries\n\nDonor 00012: CO UNDP Funding\nhttps://www.undp.org/es/colombia", 'Donor 12641: The United Nations Multi-Partner Trust Fund for Sustaining Peace in Colombia / (Previously Known As Mptf-Colombia Post-Conflict Unmptf)\nhttps://mptf.undp.org/\n\nDonor 00012: CO UNDP Funding\nhttps://www.undp.org/es/colombia', 'GEF/PNUD', 'GEF /PNUD', 'GCF /PNUD', 'USAID/ PNUD', "['GOVERNMENT OF JAPAN', 'UNITED NATIONS DEVELOPMENT PRO']", 'GEF, UNDP', 'European Union $13.5M', 'Japan $ 2,2  (2023)\n', 'Austria (ADA) $ 455,455.53 (2024)\nSwitzerland (SDC)$ 986,845.96 (2024)', 'Denmark: 2024\t= $1,217,005, 2025 = $1,887,018, 2026 = $910,065, 2027 = $254,178', 'Italy: 2024 = $7,813,710, 2025 = $3,151,201\n\nSweden: 2024 = $9,560,229.01', 'Sweden: 2024 = $182,338.04, 2025 = $1,689,690.26, 2026 = $1,686,532.06, 2027 = $1,137,162.54, 2028 = $299,093.38\n\nNorway: 2024 = $592,708.17, 2025 = $1,063,419.99, 2026 = $747,128,23\t ', "['GOVERNMENT OF DOMINICAN REPUBLIC']", 'Global Fund', 'Trac 2 Funds', "['GOVERNMENT OF SAUDI ARABIA']", 'Joint SDG Fund', "['Deutsche Gesellschaft fÃ¼r Internationale Zusammenarbeit', 'UNITED NATIONS DEVELOPMENT PRO']", '(1) MOFCOM: 1,000,000\n(2) Co-financing: 1,042,396', '\n(1) GEF: 4,480,500.00\n(2) Co-financing: 69,045,899', '(1) GEF: 2,890,826\n(2) Co-financing: 13,773,751', '\xa0UNDP Headquaters:136,000', 'UNDP: 270,000', "['GOVERNMENT OF BAHRAIN', 'Office of Minister of Energy']", 'ADB, UNDP', "['FOOD AND AGRICULTURE ORGANIZATION OF THE UNITED NATIONS']", "['MPTFO - Joint SDG Fund (previously known as The Joint Fund for the 2030 Agenda)']", 'Venezuela ? ', 'FCDO', 'TRAC 2', 'Global Fund (Next phase will be funded by GCF)', 'Climate Promise ', 'SIDA', 'Climateworks Foundation, Montreal Protocol, New Zealand, Canada, GIZ', "['GOVERNMENT OF SRI LANKA', 'PRIVATE SECTOR', 'UNITED NATIONS DEVELOPMENT PRO']", "['MINISTRY OF COMMERCE, CHINA']", "['MONTREAL PROTOCOL']", "['SWEDISH INTERNATIONAL DEVELOPMENT COOPERATION (SIDA)']", "['Korean Environmental Industry & Technology Institute', 'UNDP Funding Windows', 'UNITED NATIONS DEVELOPMENT PRO']", 'Japan, Thailand, Private Sector, Citi Foundation', 'UNDP/GEF', "['GOVERNMENT OF GERMANY', 'GOVERNMENT OF JAPAN']", 'Government of Croatia', 'Government Of Albania; MPTF-SDGs Acceleration Fund for Albania with financing of the Government of Denmark and United Kingdom', 'European Commision', "['GOVERNMENT OF DEMOCRATIC REPUBLIC OF THE', 'UNITED NATIONS DEVELOPMENT PRO']", 'PNUD', "['CAFI National Investment Programme Framework', 'MPTF- Cntrl African Forest Initiative fund (AFI00)', 'UNITED NATIONS DEVELOPMENT PRO']", 'GEF\nUNDP', "['MPTFO-Libyan Electricity Sector Stabilization and Transition Support (LESST) Joint Programme']", "['GOVERNMENT OF CHINA']", ...

# %% [markdown]
# <h4> update country metadata </h4>

# %%
updatedCountryList=[]

#add country stats on project and output count and budget to metadata
for index,row in countryMetadata.iterrows():
    country=row['Country Code']
        
    filteredOutputs=outputDfComplete[outputDfComplete["Country Code"]==country]
    
    row["Project Count"]=len(filteredOutputs["Project ID"].unique().tolist())
    row["Output Count"]=len(filteredOutputs)
    row["Budget Total"]=filteredOutputs["Budget"].sum()

    updatedCountryList.append(row)    

updatedCountryMeta=pd.DataFrame.from_records(updatedCountryList)


##add direct and indirect beneficiaries count to countryMeta

updatedCountryMeta["Direct Beneficiaries"]=updatedCountryMeta["Country Code"].apply(lambda x: outputDfComplete[outputDfComplete["Country Code"]==x]["Direct Beneficiaries"].sum())
# updatedCountryMeta["Indirect Beneficiaries"]=updatedCountryMeta["Country Code"].apply(lambda x: outputDfComplete[outputDfComplete["Country Code"]==x]["Indirect Beneficiaries"].sum())

updatedCountryMeta.to_csv("../02_Output/03_Countries/countryMetadata.csv")

# %% [markdown]
# <h2> Analyze, Plot, and Export </h2>

# %% [markdown]
# <h4> analyze beneficiary outputs </h4>

# %%
beneTiers={}
for index,row in directConversion.iterrows():
    if row["Tier"] not in beneTiers:
        beneTiers[row["Tier"]]=[]
    beneTiers[row["Tier"]].append(row["Beneficiary Category"])

summaryDfList=[]

def getBeneSums(row,df):

    row["Direct Beneficiaries"]=df["Direct Beneficiaries"].sum()
    row["Energy Access"]=df[df["Beneficiary Category Pre"].isin(["Electricity Access","Energy (MW added)","Clean Cooking"])]["Direct Beneficiaries"].sum()
    row["Productive Use"]=df[df["Beneficiary Category Pre"].isin(productiveUseCategories)]["Direct Beneficiaries"].sum()
    dfNoDuplicates=df.drop_duplicates(subset='Project ID') ##
    row["Budget Sum (M USD)"]=dfNoDuplicates["Budget"].sum()
    
    #row["Indirect Beneficiaries"]=df["Indirect Beneficiaries"].sum()
    
    #row["Energy Saved (MJ)"]=df["Energy Saved (MJ)"].sum()

    return row


def getProjectCounts(row,df):
    projectIds=df["Project ID"].unique().tolist()
    row["Project Count"]=len(projectIds)    
    return row

def getCountryCounts(row,df):
    countryCodes=df["Country Code"].unique().tolist()
    row["Country Count"]=len(countryCodes)    
    return row
    
    
def getSummaryInfo(row,df):
    row=getBeneSums(row,df)
    row=getProjectCounts(row,df)
    row=getCountryCounts(row,df)
    return row
    
    
#
    
def generateSummaries(outputDfComplete):##execute function
    
    for region in ["All","RBLAC","RBA","RBAS","RBEC","RBAP","SIDS","LDC","LLDC","Africa","Sahel"]:

        if region=="All":
            outputDfRegion=outputDfComplete
        elif region in ["SIDS","LDC","LLDC","Sahel"]:
            outputDfRegion=outputDfComplete[outputDfComplete[region]==region]
        elif region in ["Africa"]:
            outputDfRegion=outputDfComplete[outputDfComplete["continent-region"]==region]
        else:
            outputDfRegion=outputDfComplete[outputDfComplete["Region"]==region]
        
        for projectType in ["Total","VF","Non-VF"]:

            if projectType=="Total":
                outputDfFiltered=outputDfRegion
            else:
                outputDfFiltered=outputDfRegion[outputDfRegion["VF or Non-VF"]==projectType]

            ##first add values for unfiltered 
            summaryDfList.append(getSummaryInfo({"Region":region,"Category":"All","Subcategory":"All","VF or Non-VF":projectType},outputDfFiltered))

            for economy in outputDfFiltered["Economy"].dropna().unique().tolist():
                summaryDfList.append(getSummaryInfo({"Region":region,"Category":"Economy","Subcategory":economy,"VF or Non-VF":projectType},outputDfFiltered[outputDfFiltered["Economy"]==economy]))

            for hdi in outputDfFiltered["HDI"].dropna().unique().tolist():
                summaryDfList.append(getSummaryInfo({"Region":region,"Category":"HDI","Subcategory":hdi,"VF or Non-VF":projectType},outputDfFiltered[outputDfFiltered["HDI"]==hdi]))

    #         for region in outputDfFiltered["Region"].dropna().unique().tolist():
    #             summaryDfList.append(getSummaryInfo({"Category":"Region","Subcategory":region,"VF or Non-VF":projectType},outputDfFiltered[outputDfFiltered["Region"]==region]))

            #for donorCategory in ["Government","UN Agencies","Other","UN Pooled Funds","European Union","DFI","Private Sector"]:

            for beneTier in beneTiers:
                summaryDfList.append(getSummaryInfo({"Region":region,"Category":"Beneficiary Tier","Subcategory":beneTier,"VF or Non-VF":projectType},outputDfFiltered[outputDfFiltered["Beneficiary Category Pre"].isin(beneTiers[beneTier])]))

            for beneCategory in outputDfFiltered["Beneficiary Category Pre"].dropna().unique().tolist():
                df=outputDfFiltered[outputDfFiltered["Beneficiary Category Pre"]==beneCategory]
        #         if beneCategory=="Policy or Regulatory Framework":
        #             for taxonomy in outputDfFiltered["Policy-taxonomy"].dropna().unique().tolist():     
        #                 summaryDfList.append(getSummaryInfo({"Category":"Beneficiary Category","Subcategory":"Policy - "+taxonomy,"VF or Non-VF":projectType},df[df["Policy-taxonomy"]==taxonomy]))
        #         else:
                summaryDfList.append(getSummaryInfo({"Region":region,"Category":"Beneficiary Category","Subcategory":beneCategory,"VF or Non-VF":projectType},df))
    return pd.DataFrame.from_records(summaryDfList)

summaries=generateSummaries(outputDfComplete)
summaryDf=pd.DataFrame.from_records(summaries)
summaryDf.to_csv("../02_Output/05_Summary/summaryDf.csv")

# %%
def create_sideways_bar_chart(df, category_name, value, custom_chart_info):
    # Set default metadata values
    chart_info = {
        'width': 8,
        'height': .8,
        'style': 'whitegrid',
        'palette': 'pastel',
        'xlabel': 'Values',
        'ylabel': 'Subcategories',
        'title': f'{category_name} - Sideways Bar Chart',
        'xlabel_fontsize': 12,
        'ylabel_fontsize': 12,
        'title_fontsize': 14
    }

    # Update metadata with provided values (if any)
    if custom_chart_info:
        chart_info.update(custom_chart_info)

    # Filter DataFrame for the specified category
    category_data = df[df["Category"] == category_name]

    # Create a horizontal bar chart using Seaborn
    plt.figure(figsize=(chart_info['width'], chart_info['height']*len(category_data)))  # Set the figure size
    
    # Customize Seaborn style and color palette
    sns.set(style=chart_info['style'])
    colors = sns.color_palette(chart_info['palette'])
    
    if isinstance(value,list):
        pass
        #####
        
    elif isinstance(value,str):
        # Create the sideways bar chart using Seaborn's barplot
        sns.barplot(x=value, y="Subcategory", data=category_data, palette=colors)

    # Customize labels and title
    plt.xlabel(chart_info['xlabel'], fontsize=chart_info['xlabel_fontsize'])
    plt.ylabel(chart_info['ylabel'], fontsize=chart_info['ylabel_fontsize'])
    plt.title(chart_info['title'], fontsize=chart_info['title_fontsize'])
    
    # Display the chart
    plt.show()

# # Sample DataFrame
# data = {
#     'Category': ['A', 'A', 'A', 'B', 'C', 'C'],
#     'Subcategory': ['Sub1', 'Sub2', 'Sub3', 'Sub2', 'Sub1', 'Sub2'],
#     'Direct Beneficiaries': [40, 60, 35, 90, 50, 70],
#     'Budget Sum (M USD)': [10, 15, 20, 25, 30, 35]
#     #'Indirect Beneficiaries': [20, 30, 25, 40, 15, 25]
# }

# df = pd.DataFrame(data)

# chart_info = {
#     'palette': 'deep',
#     'xlabel': 'Custom Values',
#     'ylabel': 'Custom Categories',
#     'title': 'Custom Sideways Bar Chart'
# }

# # Example usage: Generate sideways bar chart for Category 'A' and 'Direct Beneficiaries'
# create_sideways_bar_chart(df, 'A','Direct Beneficiaries',chart_info)

# %%
def plotCategoryBeneficiaries(category,value,vf):
    # Extract data from DataFrame
    df=summaryDf[summaryDf["Category"]==category]
    df=df[df["VF or Non-VF"]==vf]
    df=df[df["Direct Beneficiaries"]>0]

    chart_info = {
        'palette': 'deep',
        'xlabel': 'Direct Beneficiaries',
        'ylabel': category,
        'title': "Direct Beneficiaries by "+ category
    }

    # Example usage: Generate sideways bar chart for Category 'A' and 'Direct Beneficiaries'
    create_sideways_bar_chart(df, category,value,chart_info)

# %%
plotCategoryBeneficiaries("Beneficiary Tier","Direct Beneficiaries","Total")

# %%
plotCategoryBeneficiaries("Economy","Direct Beneficiaries","Total")

# %%
plotCategoryBeneficiaries("Beneficiary Category","Direct Beneficiaries","Total")

# %%
plotCategoryBeneficiaries("HDI","Direct Beneficiaries","Total")

# %%
plotCategoryBeneficiaries("Grouping","Direct Beneficiaries","Total")

# %%
#df=df[df["Category"].isin(["Electricity Access","Energy (MW added)"])]

# %%
def plotCountryBeneficiaries():
    # Extract data from DataFrame
    
    
    df=updatedCountryMeta[updatedCountryMeta['Country Code'].isin(["BRA", "SSD", "COL", "PAK", "TUR", "TCD", "PRY", "ALB"])]
    
    #df=updatedCountryMeta.nlargest(10, 'Direct Beneficiaries')
       
    x = df['Country Code']
    y1 = df['Direct Beneficiaries']
    #y2 = df['Indirect Beneficiaries']

    # Create the stacked bar chart
    plt.bar(x, y1, label='Direct Beneficiaries')
    #plt.bar(x, y2, bottom=y1, label='Indirect Beneficiaries')

    # Add labels and title
    plt.xlabel('Countries')
    plt.ylabel('Beneficiaries (Millions of people)')
    plt.title("Beneficiaries by Country")
    plt.legend()

    # Display the chart
    plt.show()

plotCountryBeneficiaries()

# %%
def plotCountryBeneficiaries():
    # Extract data from DataFrame
    
    
    
    df=updatedCountryMeta.nlargest(10, 'Direct Beneficiaries')
       
    x = df['Country Code']
    y1 = df['Direct Beneficiaries']
    #y2 = df['Indirect Beneficiaries']

    # Create the stacked bar chart
    plt.bar(x, y1, label='Direct Beneficiaries')
    #plt.bar(x, y2, bottom=y1, label='Indirect Beneficiaries')

    # Add labels and title
    plt.xlabel('Countries')
    plt.ylabel('Beneficiaries (Millions of people)')
    plt.title("Beneficiaries by Country")
    plt.legend()

    # Display the chart
    plt.show()

plotCountryBeneficiaries()

# %% [markdown]
# <h4> Donor analysis </h4>

# %%
# calculate donors stats (donors, beneficiaries)
# matplotlib

# %%
# projectDonors={}

# for project in projectDf["Project ID"]:
#     donorList=[]
#     for donor in projectDf["Donors"].split(",")
#         donor=donor.replace("'", "").replace("[", "").replace("]", "")

#         split=donor.split("$")
#         if len(split)>1:
#             if testNumeric(split[0]):
#                 val=split[0]
#                 donor=split[1]
#             else if testNumeric(split[1]):
#                 val=split[1]
#                 donor=split[0]
#             else:
#                 donor=split
#         donorList.append(donor)
#     projectDonors[project]=

# %% [markdown]
# <h3> run each output through chatgpt to generate description </h3>

# %%
system_prompt="You are a consultant studying outputs from UNDP energy-related projects. Generate a short description (<50 words) on the following output based on the information provided. Don't included all the project info, just the specific details of that output. Don't use the name of the country in the result (AKA don't write 'in Colombia'). Start the sentence with the action verb, as in 'Provide access to 500 million' or 'Create 1000 jobs', so don't include at the start 'This project aims to'."

# OpenAI API configuration
load_dotenv()
openai.api_type = "azure"
openai.api_key = os.getenv("api_key_azure")
openai.api_base = os.getenv("AZURE_OPENAI_ENDPOINT")
openai.api_version = os.getenv("api_version")
openai_deployment = "sdgi-gpt-35-turbo-16k"

def get_output_description(output_info):
    prompt = f"{system_prompt}\n{output_info}"
   
    response = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0,
                    messages=[
                        {"role": "user", "content": prompt},
                    ]
                )
    output_description = response.choices[0].message.content
    return output_description

test_info='{"indicator":"number of beneficiaries","technology":"solar","target":"10000","country":"colombia"}'

get_output_description(test_info)
# Out:
# 'Provide solar energy access to 10,000 beneficiaries in Colombia.'

# %%
def string_to_short_sha256_hash(input_string, num_bytes=4):
    # Compute SHA-256 hash
    hash_obj = hashlib.sha256(input_string.encode())
    # Truncate to the desired number of bytes
    return str(int.from_bytes(hash_obj.digest()[:num_bytes], 'big'))

# Example usage
input_string = "Your 400 character string goes herharacter string goes herharacter string goes herharacter string goes herharacter string goes herharacter string goes herharacter string goes herharacter string goes herharacter string goes here..."
hash_value = string_to_short_sha256_hash(input_string)
print(hash_value)
# Out:
# 3845348438

# %%
##this code should be used if the AI generated descriptions are needed.
def generateAiDescriptions():
    outputDescriptionFile="../02_Output/02_Outputs/outputDescriptions.json"
    with open(outputDescriptionFile, 'r') as file:
        outputDescriptions = json.load(file)
    for index, row in outputDfComplete.iterrows():
        if index<100000:#lower number for testing
            row_hash=string_to_short_sha256_hash(' '.join(str(value) for value in row))
            print(row_hash)
            if row_hash not in outputDescriptions:
                row_dict=row.to_dict()
                row_dict["Project Description"]=projectDf[projectDf["Project ID"]==row["Project ID"]].iloc[0]["description"]
                description=get_output_description(row_dict)
                print(description)
                outputDescriptions[row_hash]=description
                outputDfComplete.loc[index, 'Description'] = description
            else:
                outputDfComplete.loc[index, 'Description'] = outputDescriptions[row_hash]
                print(index,"already complete.")

    print(outputDescriptions)

    with open(outputDescriptionFile, 'w') as file:
        json.dump(outputDescriptions, file) 
    
#generateAiDescriptions()

# %%
##this code uses the manual output descriptions file

outputDescriptionsManual = pd.read_csv("../01_Input/07_Outputs/Output Descriptions Manual.csv")

outputDfComplete = outputDfComplete.merge(outputDescriptionsManual[['Output ID', 'Description']], on='Output ID', how='left')

print(outputDfComplete)
# Out:
#      Project ID                                              Title  \
# 0      117913.0      Résilience des communautés et des écosystèmes
# 1      117913.0      Résilience des communautés et des écosystèmes
# 2      117913.0      Résilience des communautés et des écosystèmes
# 3      134793.0  Accès aux énergies renouvelables en milieu rur...
# 4      134793.0  Accès aux énergies renouvelables en milieu rur...
# ...         ...                                                ...
# 1174     130610                      Multilateral Support to COP27
# 1175   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1176   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1177   132255.0  Projet d’Electrification  Rurale en Zones Isol...
# 1178   131201.0                                         Paix Verte
#
#                                         Link       Budget  \
# 0     http://open.undp.org/projects/00117913    3459600.0
# 1     http://open.undp.org/projects/00117913    3459600.0
# 2     http://open.undp.org/projects/00117913    3459600.0
# 3     http://open.undp.org/projects/00134793    1431552.0
# 4     http://open.undp.org/projects/00134793    1431552.0
# ...                                      ...          ...
# 1174                                 Qunatum    1500000.0
# 1175                                     NaN  329490000.0
# 1176                                     NaN  329490000.0
# 1177                                     NaN  329490000.0
# 1178                                     NaN     157000.0
#
#      Beneficiary Category                                          Indicator  \
# 0       Clean Electricity  Nombre de ménages ayant accès à l’énergie sola...
# 1                   Other  Pourcentage des producteurs de charbon dans le...
# 2                   Other  Pourcentatge des femmes productrices de charbo...
# 3       Clean Electricity  Nombre de ménages dans les villages ciblés, y ...
# 4                   Other  Nombre de personnes bénéficiant des services d...
# ...                   ...                                                ...
# 1174                Solar  Electricity generation capacity shfited from f...
# 1175    Clean Electricity  1. Percentage of populations, disaggregated by...
# 1176                Other  Number of people who benefits from training fo...
# 1177                Other                                                NaN
# 1178        Clean Cooking  Nombre d’initiatives d’utilisation des énergie...
#
#      Baseline  Target                                              Notes  \
# 0           0  3697.5  Nombre de ménages dirigés par les hommes: 650,...
# 1           0     460  Il ya 576 productrices de chanbons qui ont été...
# 2           0     460  Il ya 576 productrices de chanbons qui ont été...
# 3           0  6525.0  Nombre de ménages dirigés par les hommes: 1200...
# 4       10000   50000                  Environ 50 000 personnes au Total
# ...       ...     ...                                                ...
# 1174        0     1.5  The added PV capacities will be mainly impleme...
# 1175      0.0  300000  The objective of PERZI is to create the condit...
# 1176      NaN    1000                                                NaN
# 1177      NaN     200                                                NaN
# 1178      0.0  1731.0  The Biogas initiative is a component of the “G...
#
#                    Donors  ...  LDC SIDS LLDC     HDI  Sahel  \
# 0                    UNDP  ...  LDC  NaN  NaN     Low    NaN
# 1                    UNDP  ...  LDC  NaN  NaN     Low    NaN
# 2                    UNDP  ...  LDC  NaN  NaN     Low    NaN
# 3                    UNDP  ...  LDC  NaN  NaN     Low    NaN
# 4                    UNDP  ...  LDC  NaN  NaN     Low    NaN
# ...                   ...  ...  ...  ...  ...     ...    ...
# 1174                   EU  ...  NaN  NaN  NaN    High    NaN
# 1175  Gouvernment, UNDP,   ...  LDC  NaN  NaN  Medium  Sahel
# 1176  Gouvernment, UNDP,   ...  LDC  NaN  NaN  Medium  Sahel
# 1177  Gouvernment, UNDP,   ...  LDC  NaN  NaN  Medium  Sahel
# 1178                  PBF  ...  LDC  NaN  NaN  Medium  Sahel
#
#      Direct Conversion Factor Direct Beneficiaries    Output Category  \
# 0                           1               3697.5      Energy Access
# 1                           0                  0.0              Other
# 2                           0                  0.0              Other
# 3                           1               6525.0      Energy Access
# 4                           0                  0.0              Other
# ...                       ...                  ...                ...
# 1174                    17500              26250.0  Energy Transition
# 1175                        1             300000.0      Energy Access
# 1176                        0                  0.0              Other
# 1177                        0                  0.0              Other
# 1178                        1               1731.0      Energy Access
#
#         Beneficiary Category Pre  \
# 0             Electricity Access
# 1                            nan
# 2                            nan
# 3             Electricity Access
# 4                            nan
# ...                          ...
# 1174           Energy (MW added)
# 1175          Electricity Access
# 1176  Capacity Building Training
# 1177                         nan
# 1178               Clean Cooking
#
#                                             Description
# 0     Provide access to solar energy for 3697 househ...
# 1     Increase the percentage of coal producers in t...
# 2     Convert 460 female charcoal producers to alter...
# 3     Provide access to solar energy for 1500 househ...
# 4     Provide solar energy services to approximately...
# ...                                                 ...
# 1174  Shift 1.5 MW of electricity generation capacit...
# 1175  Provide access to clean electricity for 300,00...
# 1176  Train 1000 people in energy business and energ...
# 1177  Electrify 200 isolated rural areas through the...
# 1178  Provide low-income households with a source of...
#
# [1179 rows x 40 columns]

# %% [markdown]
# <h4> Export xlsx with each df as a separate sheet </h4>

# %%
###Export full xlsx with all dfs as tabs
# Create ExcelWriter object
writer = pd.ExcelWriter('../02_Output/00_Final Results/Moonshot Tracker Results - Auto.xlsx', engine='xlsxwriter')

# Write DataFrames to separate sheets
summaryDf.to_excel(writer, sheet_name='Summary', index=False)
outputDfComplete.to_excel(writer, sheet_name='Outputs', index=False)
projectDf.to_excel(writer, sheet_name='Projects', index=False)
updatedCountryMeta.to_excel(writer, sheet_name='Countries', index=False)
#donorDf.to_excel(writer, sheet_name='Donors', index=False)

# Save the Excel file
writer.save()

# %%
valuesDict={"Education Services":"Education","Agriculture and Food System":"Agriculture","Water Services":"Water","Infrastructure Services":"Infrastructure","Health Services":"Health","Transportation and E-mobility Services":"Transport"}

# %% [markdown]
# <h3> convert results to json format for dashboard </h3>

# %%
projectsJson=[]
projectDf=projectDf.fillna(np.nan).replace([np.nan], [None])
outputDfComplete=outputDfComplete.fillna(np.nan).replace([np.nan], [None])
#outputDfComplete.dropna(subset=["Beneficiary Category"], inplace=True)
outputDfComplete["Beneficiary Category"]=outputDfComplete["Beneficiary Category"].fillna("Missing")

for index,projectRow in projectDf.iterrows():
    
    newProject={}
    newProject["id"]=str(projectRow["Project ID"]).replace(".0","")
    newProject["title"]=projectRow["Project Title"]
    linkResult=urlparse(projectRow["Link"])

    if all([linkResult.scheme, linkResult.netloc]):
        newProject["link"]=projectRow["Link"]
    else:
        newProject["link"]=None

    newProject["budget"]=projectRow["Budget"]
    newProject["countryCode"]=projectRow["Country Code"]
    newProject["countryName"]=projectRow["Country"]
    try:
        if projectRow["GHG Emissions Reduction"]>0:
            newProject["ghgEmissions"]= projectRow["GHG Emissions Reduction"]
        else:
            newProject["ghgEmissions"]=None
    except:
        newProject["ghgEmissions"]=None

        
    newProject["verticalFunded"]=(projectRow["VF or Non-VF"]=="VF")
    newProject["description"]=str(projectRow["description"])
    if len(newProject["description"])<10:
        newProject["description"]="add project description"
    newProject["genderMarker"]=projectRow["Gender Marker"]
    try:
        newProject["donors"]=projectRow["Donors"].replace("[","").replace("]","").replace("'","").strip().split(",")
    except:
        newProject["donors"]=None

    if "GEN" not in newProject["genderMarker"]:
        newProject["genderMarker"]=None
    
   
    outputDfProject=outputDfComplete[outputDfComplete["Project ID"]==projectRow["Project ID"]]
    outputRow=outputDfProject.iloc[0]
    
    newProject["region"]=outputRow["Region"]
    try:
        newProject["thematics"]=outputRow["Tag"].split(",") 
    except:
        newProject["thematics"]=[]
    newProject["flagship"]=outputRow["Flagship"]
    newProject["hdiTier"]=outputRow["HDI"]    
    newProject["incomeGroup"]=outputRow["Economy"]
    newProject["specialGroupings"]=[outputRow[col] for col in ['SIDS', 'LLDC', 'LDC'] if not pd.isna(outputRow[col])]
 
    outputsJson=[]

    for index, outputRow in outputDfProject.iterrows():
        print(outputRow["Beneficiary Category"])
        newOutput={}
        newOutput["outputCategory"]=outputRow["Output Category"]
        
        if outputRow["Beneficiary Category"] in valuesDict:
            newOutput["beneficiaryCategory"]=valuesDict[outputRow["Beneficiary Category"]]
        else:
            newOutput["beneficiaryCategory"]=outputRow["Beneficiary Category"]
        if outputRow["Beneficiary Category Pre"]=="Energy (MW added)":
            try:
                newOutput["mwAdded"]=outputRow["Target"]-outputRow["Baseline"]
            except:
                if outputRow["Target"]L
                    newOutput["mwAdded"]=outputRow["Target"]
                else:
                    newOutput["mwAdded"]=0
        else:
            newOutput["mwAdded"]=0
         
        if outputRow["Beneficiary Category"]=="Efficiency":
            newOutput["energySaved"]=outputRow["Target"]
        else:
            newOutput["energySaved"]=0
            
        if outputRow["Beneficiary Category Pre"]=="Policy or Regulatory Framework":
            newOutput["policies"]=1
        else:
            newOutput["policies"]=0
            
        if outputRow["Beneficiary Category"]=="Finance":
            newOutput["finance"]=0
        else:
            newOutput["finance"]=0        


        newOutput["directBeneficiaries"]=outputRow["Direct Beneficiaries"]
        
        
        newOutput["percentFemale"]=outputRow["Gender (% female)"]
#         if newOutput["percentFemale"]==False:
#             newOutput["percentFemale"]=None
        if type(newOutput["percentFemale"])==str:
            if "%" in newOutput["percentFemale"]:
                try:
                    newOutput["percentFemale"]=float(newOutput["percentFemale"].replace('%', 'e-2'))
                except:
                    newOutput["percentFemale"]=None
        try:
            if (newOutput["percentFemale"])<1:
                newOutput["percentFemale"]=newOutput["percentFemale"]*100
        except:
            newOutput["percentFemale"]=None
        try:
            newOutput["description"]=outputRow["Description"]
        except:
            newOutput["description"]=""
        
        ## confirm numeric values are numeric
        
        for key in ["energySaved","mwAdded","directBeneficiaries","percentFemale"]:
            try:
                newOutput[key] = float(newOutput[key])
            except:    
                if newOutput[key]:
                    print(newOutput[key])
                    newOutput[key]=None
                    print(projectRow["Country"],newProject["id"],key,"nonnumeric")

        newOutput["id"]= (newProject["countryCode"]+"-"+newProject["id"] +"-"+ newOutput["beneficiaryCategory"] + "-"+str(len(outputsJson))).replace(" ","") 

        outputsJson.append(newOutput)
        
    newProject["outputs"]=outputsJson

    projectsJson.append(newProject)

print(projectsJson)
with open('../02_Output/06_Dashboard/moonshotData.json', 'w') as jsonfile:
    json.dump(projectsJson, jsonfile)
# Out:
# Clean Electricity
# Other
# Other
# Clean Electricity
# Other
# Other
# Clean Electricity
# Policy - Overall
# Solar
# Policy - Overall
# Agriculture and Food System
# Other
# Solar
# Health Services
# Other
# Solar
# Some Sources
# Clean Electricity
# Clean Electricity
# Education Services
# Health Services
# Policy - Renewable Energy
# Other
# Clean Electricity
# Other
# Other
# Efficiency
# Clean Electricity
# Other
# Policy - Renewable Energy
# Wind
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other
# Other
# Other
# Other
# Clean Electricity
# Other
# Other
# Other
# Other
# Some Sources
# 132 target
# Samoa 5669 mwAdded nonnumeric
# Clean Electricity
# Other
# Policy - Other
# Policy - Other
# Transportation and E-mobility Services
# Other
# Other
# Policy - Renewable Energy
# Other Energy Services
# Transition Missing
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other Energy Services
# Efficiency
# Other
# Other
# Transportation and E-mobility Services
# Health Services
# Education Services
# Clean Cooking
# Water Services
# Other
# Transition Missing
# 0.264 MW
# Brazil 143571 mwAdded nonnumeric
# Transportation and E-mobility Services
# Transition Missing
# Other
# Other
# Other
# Transportation and E-mobility Services
# Waste
# Policy - Renewable Energy
# Policy - Renewable Energy
# Clean Electricity
# Agriculture and Food System
# Education Services
# Other
# Agriculture and Food System
# Water Services
# Health Services
# Other
# Health Services
# Clean Electricity
# Some Sources
# Other
# Water Services
# Health Services
# Clean Electricity
# Solar
# Other
# Policy - Energy Efficiency
# Other
# Transportation and E-mobility Services
# Other
# Policy - Energy Efficiency
# Clean Electricity
# Clean Electricity
# Other
# Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other
# Policy - Electricity Access
# Other
# Policy - Electricity Access
# Other
# Transportation and E-mobility Services
# Other
# Transportation and E-mobility Services
# Policy - Other
# Policy - Other
# Other
# Other
# Transportation and E-mobility Services
# Policy - Energy Efficiency
# Solar
# Solar
# Other
# Other
# Solar
# Other
# Water Services
# Transition Missing
# Other
# Other
# Other
# Efficiency
# Energy Infrastructure Services
# Clean Electricity
# Other
# Clean Electricity
# Policy - Electricity Access
# Solar
# Policy - Electricity Access
# Policy - Renewable Energy
# Geothermal
# Clean Electricity
# Water Services
# solar
# Clean Electricity
# Efficiency
# Education Services
# Other
# Clean Electricity
# Clean Electricity
# Solar
# Policy - Renewable Energy
# Transportation and E-mobility Services
# Other
# Other Energy Services
# Policy - Overall
# Other
# Other
# Efficiency
# Policy - Electricity Access
# Clean Electricity
# Other
# Policy - Energy Efficiency
# Policy - Renewable Energy
# Other
# Policy - Other
# Other
# Clean Electricity
# Policy - Other
# Other
# Efficiency
# Other
# Other Energy Services
# Other Energy Services
# Clean Electricity
# Water Services
# Other
# Other
# Clean Electricity
# Transition Missing
# Water Services
# Other
# Other
# Other
# Health Services
# Health Services
# Health Services
# Other
# Clean Electricity
# Other
# Efficiency
# Transportation and E-mobility Services
# Clean Electricity
# Other
# Policy - Renewable Energy
# Solar
# Other
# Solar
# Other
# Policy - Renewable Energy
# Solar
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Energy Infrastructure Services
# Solar
# Health Services
# Education Services
# Clean Electricity
# Clean Cooking
# Other
# Policy - Overall
# Clean Electricity
# Other
# Other
# Agriculture and Food System
# Other Energy Services
# Agriculture and Food System
# Other
# Other
# Other
# Transportation and E-mobility Services
# Other
# Transportation and E-mobility Services
# Bioenergy
# Other
# Policy - Renewable Energy
# Efficiency
# Efficiency
# Clean Electricity
# Other
# Clean Electricity
# Other
# Clean Electricity
# Other
# Other
# Other
# Other
# Other
# Other
# Efficiency
# Other
# Clean Electricity
# Policy - Energy Efficiency
# Other
# Efficiency
# Efficiency
# Other
# Other
# Other
# Other
# Clean Electricity
# Other
# Solar
# Other
# Other
# Other
# Clean Electricity
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Policy - Overall
# Other
# Other
# Other
# Policy - Clean Cooking
# Policy - Clean Cooking
# Policy - Clean Cooking
# Policy - Clean Cooking
# Other Energy Services
# Policy - Renewable Energy
# Policy - Overall
# Clean Electricity
# Transition Missing
# Clean Cooking
# Health Services
# Water Services
# Education Services
# Policy - Renewable Energy
# Other
# Other
# Other
# Clean Electricity
# Solar
# Clean Electricity
# Agriculture and Food System
# Other Energy Services
# Clean Cooking
# Other
# Health Services
# Clean Electricity
# Education Services
# Other
# Efficiency
# Clean Electricity
# Clean Cooking
# Other
# Clean Electricity
# Some Sources
# 4986 MW added
# Venezuela missing-VEN-1 mwAdded nonnumeric
# Some Sources
# Clean Electricity
# Education Services
# Other Energy Services
# Health Services
# Other
# Clean Electricity
# Some Sources
# Clean Electricity
# Clean Electricity
# Other
# Policy - Renewable Energy
# Solar
# Some Sources
# Health Services
# Energy Infrastructure Services
# Water Services
# Clean Electricity
# Other
# Transition Missing
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Clean Electricity
# Other
# Policy - Overall
# Policy - Energy Efficiency
# Policy - Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Transportation and E-mobility Services
# Policy - Renewable Energy
# Agriculture and Food System
# Other
# Other
# Agriculture and Food System
# Agriculture and Food System
# Clean Electricity
# Hydro
# Solar
# installation of the 560 kW of PVs in 10 municipal buildings
# Albania 142609 mwAdded nonnumeric
# Clean Electricity
# Other
# Education Services
# Education Services
# Education Services
# Education Services
# Education Services
# Clean Electricity
# Unknown
# Clean Electricity
# Clean Electricity
# Agriculture and Food System
# Clean Electricity
# Clean Electricity
# Health Services
# Efficiency
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Transition Missing
# 108 MW
# Ukraine 134106 mwAdded nonnumeric
# Transition Missing
# 29.9 MW
# Ukraine 134106 mwAdded nonnumeric
# Transition Missing
# 80 MW
# Ukraine 134106 mwAdded nonnumeric
# Transition Missing
# 90.6 MW
# Ukraine 134106 mwAdded nonnumeric
# Clean Electricity
# Transition Missing
# 6.7 MW
# Ukraine 134106 mwAdded nonnumeric
# Other
# Other
# Transition Missing
# 14 MW
# Ukraine 134106 mwAdded nonnumeric
# Transition Missing
# 40 MW
# Ukraine 134106 mwAdded nonnumeric
# Transition Missing
# 12 MW
# Ukraine 134106 mwAdded nonnumeric
# Other
# Transition Missing
# 6.5 MW
# Ukraine 1003605 mwAdded nonnumeric
# Clean Electricity
# Transition Missing
# 10.2 MW
# Ukraine 1003605 mwAdded nonnumeric
# Clean Electricity
# Clean Electricity
# Health Services
# Education Services
# Water Services
# Solar
# Clean Electricity
# Other
# Clean Electricity
# Health Services
# Clean Electricity
# Hydro
# t
# Dem. Rep. of the Congo 4690 mwAdded nonnumeric
# Policy - Electricity Access
# Policy - Electricity Access
# Policy - Clean Cooking
# Clean Cooking
# Clean Cooking
# Clean Electricity
# Solar
# Hydro
# Water Services
# Policy - Electricity Access
# Health Services
# Education Services
# Clean Cooking
# Policy - Renewable Energy
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Energy Infrastructure Services
# Other
# Clean Electricity
# Other
# Other
# Other
# Transportation and E-mobility Services
# Agriculture and Food System
# Other
# Water Services
# Policy - Other
# Other
# Agriculture and Food System
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Policy - Other
# Agriculture and Food System
# Other
# Efficiency
# Efficiency
# Efficiency
# Efficiency
# Other
# Efficiency
# Efficiency
# Clean Electricity
# Policy - Energy Efficiency
# Efficiency
# Other
# Other
# Other
# Other
# Efficiency
# 430 buildings
# Bosnia and Herzegovina 5882 energySaved nonnumeric
# Efficiency
# Other
# Other Energy Services
# Other Energy Services
# Policy - Other
# Other
# Other
# Clean Electricity
# Solar
# Health Services
# Education Services
# Other
# Other Energy Services
# Policy - Electricity Access
# Clean Electricity
# Clean Electricity
# Other Energy Services
# Efficiency
# Other
# Policy - Energy Efficiency
# Clean Electricity
# Solar
# Policy - Renewable Energy
# Other
# Health Services
# Education Services
# Other
# Other
# Policy - Renewable Energy
# Other
# Unknown
# Clean Electricity
# Other
# Other
# Other
# Other
# Other
# Solar
# Agriculture and Food System
# Other
# Other
# Other
# Policy - Renewable Energy
# Transition Missing
# Transportation and E-mobility Services
# Transportation and E-mobility Services
# Clean Cooking
# Solar
# Other
# Other
# Some Sources
# Other
# Other
# Other
# Other
# Other
# Clean Electricity
# Education Services
# Solar
# Other
# Bioenergy
# Other
# Policy - Renewable Energy
# Other
# Policy - Energy Efficiency
# Other
# Other
# Other
# Clean Electricity
# Other
# Clean Electricity
# Clean Cooking
# Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Clean Cooking
# Some Sources
# Other
# Other
# Other Energy Services
# Clean Electricity
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Other
# Other
# Other
# Clean Electricity
# Other
# Other
# Clean Electricity
# Other
# Policy - Electricity Access
# Other
# Other
# Policy - Renewable Energy
# Other
# Other
# Clean Cooking
# Solar
# Agriculture and Food System
# Other
# Solar
# Other
# Policy - Energy Efficiency
# Other
# Other
# Other
# Other
# Other
# Other
# Clean Electricity
# Other
# Other
# Transportation and E-mobility Services
# Energy Infrastructure Services
# Other Energy Services
# Solar
# Clean Electricity
# Solar
# Transportation and E-mobility Services
# Other
# Other
# Agriculture and Food System
# Agriculture and Food System
# Solar
# Solar
# Transportation and E-mobility Services
# Other
# Other
# Other
# Other
# Other
# Other
# Policy - Other
# Other
# Other
# Other
# Other
# Other
# Education Services
# Other
# Other
# Other
# Clean Cooking
# Clean Cooking
# Transportation and E-mobility Services
# Clean Electricity
# Other
# Clean Electricity
# Clean Electricity
# Other
# Other
# Other
# Other
# Transition Missing
# 11 MWp
# Indonesia 126434 mwAdded nonnumeric
# Energy Infrastructure Services
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Other
# Transportation and E-mobility Services
# Other
# Energy Infrastructure Services
# Other
# Other
# Other
# Efficiency
# 77.45 GWh
# Indonesia 5721 energySaved nonnumeric
# Other
# Other
# Other
# Clean Electricity
# Transition Missing
# 15 MW
# Indonesia 4673 mwAdded nonnumeric
# Efficiency
# 8550 MWh
# Indonesia 4673 energySaved nonnumeric
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Policy - Other
# Other
# Policy - Other
# Solar
# Other
# Policy - Renewable Energy
# Transportation and E-mobility Services
# Clean Electricity
# Other
# Clean Electricity
# Other
# Policy - Other
# Solar
# Other
# Other
# Other
# Other
# Other
# Policy - Energy Efficiency
# Other
# Policy - Renewable Energy
# Efficiency
# Other
# Transition Missing
# Other
# Other
# Other
# Other
# Other
# Other
# Efficiency
# Other
# Transition Missing
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Transition Missing
# Transportation and E-mobility Services
# Efficiency
# Policy - Other
# Clean Electricity
# Policy - Overall
# Energy Infrastructure Services
# Energy Infrastructure Services
# Other Energy Services
# Clean Electricity
# Clean Electricity
# Other
# Energy Infrastructure Services
# Solar
# Water Services
# Other
# Solar
# Solar
# Solar
# Other
# Efficiency
# 1 building
# Cameroon, Republic of 130710 energySaved nonnumeric
# Efficiency
# 2 building
# Cameroon, Republic of 130710 energySaved nonnumeric
# Other
# Health Services
# Other
# Policy - Overall
# Other
# Clean Electricity
# Other
# Other
# Solar
# Clean Electricity
# Other
# Clean Cooking
# Agriculture and Food System
# Energy Infrastructure Services
# Energy Infrastructure Services
# Clean Electricity
# Solar
# Other
# Policy - Renewable Energy
# Transportation and E-mobility Services
# Other
# Agriculture and Food System
# Solar
# Other
# Other
# Clean Electricity
# Solar
# Other
# Other
# Water Services
# Policy - Electricity Access
# Clean Cooking
# Transportation and E-mobility Services
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Efficiency
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Water Services
# Other
# Other
# Clean Electricity
# Clean Electricity
# Transportation and E-mobility Services
# Transportation and E-mobility Services
# Clean Cooking
# Agriculture and Food System
# Agriculture and Food System
# Agriculture and Food System
# Clean Electricity
# Bioenergy
# Other
# Other
# Other
# Other
# Clean Cooking
# Clean Cooking
# Clean Cooking
# Clean Electricity
# Clean Cooking
# Clean Cooking
# Other
# Policy - Clean Cooking
# Other
# Agriculture and Food System
# Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Health Services
# Other Energy Services
# Clean Electricity
# Other
# Hydro
# Water Services
# Clean Electricity
# Energy Infrastructure Services
# Water Services
# Agriculture and Food System
# Solar
# Clean Electricity
# Clean Electricity
# Other
# Other
# Transition Missing
# Other
# Energy Infrastructure Services
# Policy - Renewable Energy
# Other
# Other
# Other
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Other
# Clean Electricity
# Clean Cooking
# Clean Cooking
# Other
# Other
# Other
# Other
# Policy - Other
# Agriculture and Food System
# Other
# Policy - Renewable Energy
# Other Energy Services
# Energy Infrastructure Services
# Other
# Water Services
# Other
# Clean Electricity
# Health Services
# Education Services
# Other
# Policy - Energy Efficiency
# Other
# Policy - Energy Efficiency
# Policy - Energy Efficiency
# Other
# Policy - Energy Efficiency
# Other
# Other Energy Services
# Other Energy Services
# Other
# Efficiency
# Solar
# Other
# Other
# Other
# Other
# Other Energy Services
# Transition Missing
# Efficiency
# Efficiency
# Other Energy Services
# Transition Missing
# Efficiency
# Other Energy Services
# Transition Missing
# Efficiency
# Efficiency
# Solar
# Health Services
# Clean Electricity
# Clean Electricity
# Clean Cooking
# Other
# Clean Electricity
# Other
# Policy - Renewable Energy
# Other
# Other
# Clean Electricity
# Water Services
# Education Services
# Solar
# Solar
# Other
# Clean Electricity
# Education Services
# Solar
# Water Services
# Water Services
# Clean Electricity
# Other
# Other Energy Services
# Policy - Energy Efficiency
# Other
# Efficiency
# Clean Electricity
# Solar
# Transition Missing
# Other
# Other
# Other
# Other
# Other
# Clean Electricity
# Solar
# Solar
# Agriculture and Food System
# Health Services
# Water Services
# Education Services
# Other Energy Services
# Water Services
# Education Services
# Solar
# Solar
# Energy Infrastructure Services
# Other
# Other
# Other
# Transportation and E-mobility Services
# Other
# Other
# Other
# Clean Electricity
# Policy - Renewable Energy
# Other
# Other
# Other
# Other
# Other
# Some Sources
# Other
# Some Sources
# Other
# Other
# Some Sources
# Some Sources
# Clean Electricity
# Clean Cooking
# Clean Electricity
# Health Services
# Other
# Efficiency
# 52 buildings
# India 116294 energySaved nonnumeric
# Agriculture and Food System
# Health Services
# Agriculture and Food System
# Other Energy Services
# Other
# Other
# Other
# Other
# Other
# Transportation and E-mobility Services
# Other
# Other
# Clean Cooking
# Policy - Electricity Access
# Other
# Clean Electricity
# Policy - Overall
# Other
# Clean Cooking
# Health Services
# Other
# Other Energy Services
# Other
# Clean Electricity
# Solar
# Other
# Other
# Other Energy Services
# Agriculture and Food System
# Agriculture and Food System
# Clean Electricity
# Clean Electricity
# Other
# Clean Cooking
# Policy - Clean Cooking
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Transportation and E-mobility Services
# Other
# Other
# Policy - Energy Efficiency
# Other
# Policy - Renewable Energy
# Policy - Other
# Other
# Clean Electricity
# Unknown
# Other
# Clean Electricity
# Other
# Other Energy Services
# Water Services
# Energy Infrastructure Services
# Energy Infrastructure Services
# Energy Infrastructure Services
# Education Services
# Energy Infrastructure Services
# Energy Infrastructure Services
# Energy Infrastructure Services
# Water Services
# Health Services
# Energy Infrastructure Services
# Energy Infrastructure Services
# Education Services
# Energy Infrastructure Services
# Policy - Renewable Energy
# Water Services
# Transition Missing
# Other Energy Services
# Policy - Renewable Energy
# Other
# Water Services
# Clean Cooking
# Clean Electricity
# Other
# Clean Electricity
# Clean Electricity
# Water Services
# Other
# Other
# Policy - Energy Efficiency
# Policy - Energy Efficiency
# Other
# Policy - Renewable Energy
# Efficiency
# Clean Electricity
# Solar
# Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Other
# Other
# Clean Electricity
# Other
# Solar
# Policy - Renewable Energy
# Other
# Transportation and E-mobility Services
# Other
# Transition Missing
# Other
# Solar
# Agriculture and Food System
# Agriculture and Food System
# Solar
# Water Services
# Solar
# Other
# Other Energy Services
# Other
# Other
# Policy - Renewable Energy
# Clean Cooking
# Water Services
# Policy - Renewable Energy
# Policy - Overall
# Education Services
# Policy - Renewable Energy
# Some Sources
# Other
# Agriculture and Food System
# Clean Electricity
# Clean Cooking
# Agriculture and Food System
# Clean Electricity
# Clean Cooking
# Water Services
# Water Services
# Agriculture and Food System
# Agriculture and Food System
# Other
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Clean Electricity
# Transition Missing
# TBD
# Myanmar missing-MMR-1 mwAdded nonnumeric
# Clean Cooking
# Agriculture and Food System
# Health Services
# Water Services
# Education Services
# Other
# Other
# Other
# Other
# Policy - Other
# Agriculture and Food System
# Clean Electricity
# Other
# Other
# Other Energy Services
# Other Energy Services
# Bioenergy
# Policy - Other
# Other
# Other
# Other Energy Services
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other
# Other
# Other
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Policy - Renewable Energy
# Other
# Policy - Renewable Energy
# Other
# Other
# Other
# Other
# Policy - Other
# Policy - Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Policy - Renewable Energy
# Efficiency
# Other
# Other
# Other
# Clean Electricity
# Solar
# Other
# Other
# Transportation and E-mobility Services
# Other
# Policy - Renewable Energy
# Other
# Other
# Clean Electricity
# Other
# Clean Cooking
# Clean Electricity
# Other
# Some Sources
# Efficiency
# Policy - Renewable Energy
# Other
# Efficiency
# Other
# Other
# Other
# Clean Cooking
# Solar
# Solar
# Solar
# Solar
# Clean Electricity
# Other
# Other
# Clean Cooking
# [{'id': '117913', 'title': 'Résilience des communautés et des écosystèmes', 'link': 'http://open.undp.org/projects/00117913', 'budget': 3459600.0, 'countryCode': 'TGO', 'countryName': 'Togo', 'ghgEmissions': None, 'verticalFunded': False, 'description': 'Il s’agit de la promotion du développement Local basé sur l’appropriation par les populations rurales des bonnes pratiques de gestion de l’environnement à travers la promotion des écovillages', 'genderMarker': None, 'donors': ['UNITED NATIONS DEVELOPMENT PRO'], 'region': 'RBA', 'thematics': ['Just'], 'flagship': None, 'hdiTier': 'Low', 'incomeGroup': 'Low income', 'specialGroupings': ['LDC'], 'outputs': [{'outputCategory': 'Energy Access', 'beneficiaryCategory': 'Clean Electricity', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 3697.4999999999995, 'percentFemale': 24.0, 'description': 'Provide access to solar energy for 3697 households, disaggregated by households led by men and women.', 'id': 'TGO-117913-CleanElectricity-0'}, {'outputCategory': 'Other', 'beneficiaryCategory': 'Other', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 0.0, 'percentFemale': None, 'description': 'Increase the percentage of coal producers in targeted communities using efficient wood carbonization techniques with a yield of over 30% from 0 to 460. A total of 576 charcoal producers have been identified in 16 towns.', 'id': 'TGO-117913-Other-1'}, {'outputCategory': 'Other', 'beneficiaryCategory': 'Other', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 0.0, 'percentFemale': None, 'description': 'Convert 460 female charcoal producers to alternative income-generating activities in 16 villages, as part of a project promoting local development and environmental management practices in rural communities.', 'id': 'TGO-117913-Other-2'}]}, {'id': '134793', 'title': 'Accès aux énergies renouvelables en milieu rural au Togo', 'link': 'http://open.undp.org/projects/00134793', 'budget': 1431552.0, 'countryCode': 'TGO', 'countryName': 'Togo', 'ghgEmissions': None, 'verticalFunded': False, 'description': 'Accélération de l’accès aux énergies renouvelables pour l’autonomisation économique des populations en milieu rurale au Togo', 'genderMarker': None, 'donors': ['UNITED NATIONS DEVELOPMENT PRO'], 'region': 'RBA', 'thematics': ['Just'], 'flagship': None, 'hdiTier': 'Low', 'incomeGroup': 'Low income', 'specialGroupings': ['LDC'], 'outputs': [{'outputCategory': 'Energy Access', 'beneficiaryCategory': 'Clean Electricity', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 6524.999999999999, 'percentFemale': 20.0, 'description': 'Provide access to solar energy for 1500 households in 10 villages thanks to the construction of 10 solar mini-power stations, including 1,200 households led by men and 300 led by women.', 'id': 'TGO-134793-CleanElectricity-0'}, {'outputCategory': 'Other', 'beneficiaryCategory': 'Other', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 0.0, 'percentFemale': None, 'description': 'Provide solar energy services to approximately 50,000 people in rural areas of Togo, accelerating access to renewable energy for economic empowerment.', 'id': 'TGO-134793-Other-1'}, {'outputCategory': 'Other', 'beneficiaryCategory': 'Other', 'mwAdded': 0.0, 'energySaved': 0.0, 'policies': 0, 'finance': 0, 'directBeneficiaries': 0.0, 'percentFemale': None, 'description': 'Create 250 new solar energy businesses in targeted villages, with a goal of at least 500 beneficiaries, as part of a project to accelerate access to renewable energy in rural areas.', 'id': 'TGO-134793-Other-2'}]}, {'id': '1002293', 'title': 'Projet de développement des terroirs villageois sobres en carbone et résilients aux changements climatiques', 'link': 'http://open.undp.org/projects/01002293', 'budget': None, 'countryCode': 'TGO', 'countryName': 'Togo',  ...

# %%
if not isinstance("4", numbers.Number):
    print("why")
# Out:
# why

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Use the provided DataFrame
df = outputDfComplete

# ---------------------------------------------
# 1. Pie Chart of Direct Beneficiaries by Output Category
# ---------------------------------------------

# Ensure 'Direct Beneficiaries' is numeric
df['Direct Beneficiaries'] = pd.to_numeric(df['Direct Beneficiaries'], errors='coerce')

# Group by 'Output Category' and sum 'Direct Beneficiaries'
beneficiaries_by_output = df.groupby('Beneficiary Category')['Direct Beneficiaries'].sum()

# Remove any categories with zero or NaN beneficiaries
beneficiaries_by_output = beneficiaries_by_output[beneficiaries_by_output > 0]

# Plot pie chart
plt.figure(figsize=(10, 8))
beneficiaries_by_output.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.ylabel('')
plt.title('Direct Beneficiaries by Output Category')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# ---------------------------------------------
# 2. Breakdown of Number of Beneficiaries by Country HDI
#    (Y-axis in Millions of Beneficiaries)
# ---------------------------------------------

# Group by 'HDI' and sum 'Direct Beneficiaries'
beneficiaries_by_hdi = df.groupby('HDI')['Direct Beneficiaries'].sum().reset_index()

# Convert 'Direct Beneficiaries' to millions
beneficiaries_by_hdi['Direct Beneficiaries (Millions)'] = beneficiaries_by_hdi['Direct Beneficiaries'] / 1e6

# Sort HDI categories
hdi_order = ['Low', 'Medium', 'High', 'Very High']
beneficiaries_by_hdi['HDI'] = pd.Categorical(beneficiaries_by_hdi['HDI'], categories=hdi_order, ordered=True)
beneficiaries_by_hdi = beneficiaries_by_hdi.sort_values('HDI')

# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=beneficiaries_by_hdi, x='HDI', y='Direct Beneficiaries (Millions)', palette='viridis')
plt.ylabel('Number of Beneficiaries (Millions)')
plt.title('Breakdown of Number of Beneficiaries by Country HDI')
plt.tight_layout()
plt.show()

# ---------------------------------------------
# 3. Bubble Chart: Beneficiaries vs. Energy Access Percentage by Country
#    (Adjusted as per your instructions)
# ---------------------------------------------

# Read energy access data without skipping rows
energy_access = pd.read_csv(
    "../01_Input/02_Energy Data/API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_5358776/API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_5358776.csv"
)

# Get the list of year columns (assuming years are columns like '1960', '1961', etc.)
year_cols = [col for col in energy_access.columns if col.isdigit()]

# Function to get the latest available energy access percentage for each country
def get_latest_value(row):
    for year in reversed(year_cols):
        if not pd.isnull(row[year]):
            return row[year]
    return None

# Apply the function to create a new column
energy_access['Latest Energy Access Percentage'] = energy_access.apply(get_latest_value, axis=1)

# Keep necessary columns
energy_access = energy_access[['Country Code', 'Latest Energy Access Percentage']]

# Ensure 'Latest Energy Access Percentage' is numeric
energy_access['Latest Energy Access Percentage'] = pd.to_numeric(
    energy_access['Latest Energy Access Percentage'], errors='coerce'
)

# Group the df DataFrame
df_country_beneficiaries = df.groupby(['Country Code', 'Country Name', 'Region'])['Direct Beneficiaries'].sum().reset_index()

# Merge dataframes on 'Country Code'
df_beneficiaries_energy = pd.merge(df_country_beneficiaries, energy_access, on='Country Code', how='left')

# Remove rows with missing energy access data
df_beneficiaries_energy.dropna(subset=['Latest Energy Access Percentage'], inplace=True)

# Only include countries with >500,000 beneficiaries
df_beneficiaries_energy = df_beneficiaries_energy[df_beneficiaries_energy['Direct Beneficiaries'] > 500000]

# Exclude Venezuela
df_beneficiaries_energy = df_beneficiaries_energy[df_beneficiaries_energy['Country Code'] != 'VEN']

# Convert 'Direct Beneficiaries' to millions for x-axis
df_beneficiaries_energy['Direct Beneficiaries (Millions)'] = df_beneficiaries_energy['Direct Beneficiaries'] / 1e6

# Plot bubble chart with swapped axes and adjusted x-axis
plt.figure(figsize=(12, 8))

# Improve aesthetics by setting style
sns.set_style("whitegrid")

scatter = sns.scatterplot(
    data=df_beneficiaries_energy,
    x='Direct Beneficiaries (Millions)',
    y='Latest Energy Access Percentage',
    size='Direct Beneficiaries (Millions)',
    sizes=(100, 2000),
    hue='Region',
    alpha=0.7,
    edgecolor='black',
    palette='Set2',
    legend='brief'
)

# Annotate each bubble with the country name
for i, row in df_beneficiaries_energy.iterrows():
    plt.text(
        row['Direct Beneficiaries (Millions)'],
        row['Latest Energy Access Percentage'],
        row['Country Name'],
        fontsize=9,
        ha='center',
        va='center'
    )

# Set origin at (0, 0)
plt.xlim(0, )
plt.ylim(0, )

# Add labels and title
plt.xlabel('Number of Beneficiaries (Millions)')
plt.ylabel('Energy Access Percentage')
plt.title('Beneficiaries vs. Energy Access Percentage by Country (>500,000 Beneficiaries)')

# Move legend outside the plot
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
