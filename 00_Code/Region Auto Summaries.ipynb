# %%
import pandas as pd

# %%
# Function to format numbers correctly: 3 significant figures, comma for thousands
def format_number(n):
    if n >= 1e9:
        return f"{n / 1e9:.3g} billion"
    elif n >= 1e6:
        return f"{n / 1e6:.3g} million"
    elif n >= 1e3:
        return f"{int(round(n, -len(str(int(n))) + 3)):,}"  # Rounds to 3 sig figs & formats with commas
    else:
        return str(int(n))

def generate_values_dicts(file_path, sheet_name):
    # Load the Excel file
    df = pd.read_excel(file_path, sheet_name=sheet_name)

    # Get unique regions
    regions = df["Region"].unique()
    values_dicts = {}

    for region in regions:
        # Get the "Total" row for general values
        region_total = df[(df["Region"] == region) & (df["VF or Non-VF"] == "Total")].iloc[0]

        # Extract VF and Non-VF beneficiary counts correctly
        vf_row = df[(df["Region"] == region) & (df["VF or Non-VF"] == "VF")]
        nonvf_row = df[(df["Region"] == region) & (df["VF or Non-VF"] == "Non-VF")]

        vf_benis = vf_row["Direct Beneficiaries"].values[0] if not vf_row.empty else 0
        nonvf_benis = nonvf_row["Direct Beneficiaries"].values[0] if not nonvf_row.empty else 0

        # Extract Clean Cooking Beneficiaries correctly
        clean_cooking_row = df[(df["Region"] == region) & (df["VF or Non-VF"] == "Total") & (df["Subcategory"] == "Clean Cooking")]
        clean_cooking_benis = clean_cooking_row["Direct Beneficiaries"].values[0] if not clean_cooking_row.empty else 0

        # Use "Energy Access" directly for clean electricity
        clean_electricity_benis = max(region_total["Energy Access"] - clean_cooking_benis, 0)  # Ensure it's not negative

        # Extract the top 3 beneficiary categories (ONLY from "Beneficiary Tier" and excluding specific subcategories)
        category_data = df[
            (df["Region"] == region) & 
            (df["VF or Non-VF"] == "Total") & 
            (df["Category"] == "Beneficiary Category") & 
            (~df["Subcategory"].isin(["Clean Cooking", "Energy (MW added)", "Electricity Access", "Other Energy Services"]))
        ]
        category_totals = category_data.set_index("Subcategory")["Direct Beneficiaries"].to_dict()

        # Sort by highest values and pick the top 3
        sorted_categories = sorted(category_totals.items(), key=lambda x: x[1], reverse=True)
        top_categories = dict(sorted_categories[:3])

        # Extract "indirect-projects" from row where "Category" is "Beneficiary Tier" and "Subcategory" is "Policy and Regulator Frameworks"
        indirect_row = df[
            (df["Region"] == region) & 
            (df["Category"] == "Beneficiary Tier") & 
            (df["Subcategory"] == "Policy and Regulator Frameworks")  # Uses the misspelled version
        ]
        indirect_projects = indirect_row["Project Count"].values[0] if not indirect_row.empty else 0

        if region == "All":
            region_title = "globally"  # Leave blank for "All"
        elif region in ["LDC", "LLDC"]:
            region_title = "in "+ region + "s"  # Make plural: "LDCs", "LLDCs"
        else:
             region_title = "in "+ region # Default case: "in SIDS", "in Africa", etc.
        
        # Construct the dictionary for the region
        values_dicts[region] = {
            "region-title": region_title,
            "number-of-projects": format_number(region_total["Project Count"]),
            "number-of-countries": format_number(region_total["Country Count"]),
            "budget-text": format_number(region_total["Budget Sum (M USD)"]),  # No more "million"
            "direct-benis": format_number(region_total["Direct Beneficiaries"]),
            "vf-benis": format_number(vf_benis),
            "nonvf-benis": format_number(nonvf_benis),
            "clean-electricity-benis": format_number(clean_electricity_benis),
            "clean-cooking-benis": format_number(clean_cooking_benis),
            "productive-benis": format_number(region_total["Productive Use"]),
            "top-categories": {k: format_number(v) for k, v in top_categories.items()},  # Sorted dict
            "top-categories-text": ", ".join(top_categories.keys()),
            "indirect-projects": format_number(indirect_projects),
        }

    return values_dicts

def generate_summary(region_data):
    """Generate the summary text using the extracted region data."""
    summary = (
        f"The UNDP portfolio {region_data['region-title']} during the 2022 to 2025 Strategic Plan includes "
        f"{region_data['number-of-projects']} active energy-related projects across {region_data['number-of-countries']} countries. "
        f"The total budget for these projects is {region_data['budget-text']} USD, targeting {region_data['direct-benis']} direct beneficiaries. "
        f"This includes {region_data['vf-benis']} from VF projects and {region_data['nonvf-benis']} from non-VF projects.\n\n"
        f"Of those directly benefiting, {region_data['clean-electricity-benis']} are gaining access to clean electricity, "
        f"and {region_data['clean-cooking-benis']} are gaining access to clean cooking. Additionally, "
        f"{region_data['productive-benis']} people benefit from productive uses of energy, including "
    )

    # Add top categories
    top_category_items = [f"{v} in {k}" for k, v in region_data["top-categories"].items()]

    if len(top_category_items) > 1:
        top_categories_text = ", ".join(top_category_items[:-1]) + ", and " + top_category_items[-1]
    else:
        top_categories_text = top_category_items[0] if top_category_items else ""

    if top_categories_text:
        summary += top_categories_text + ". "


    # Add indirect projects
    summary += (
        f"{region_data['indirect-projects']} projects also include outputs related to supporting policy or regulatory frameworks, "
        f"capacity building, or other system benefits that provide indirect benefits."
    )

    return summary

# Set file path and sheet name
file_path = "../02_Output/00_Final Results/Moonshot Tracker Results - Auto.xlsx"
sheet_name = "Summary"

# Generate values dictionary
values_dicts = generate_values_dicts(file_path, sheet_name)

# Generate and print summaries for all regions
for region, region_data in values_dicts.items():
    print(generate_summary(region_data))
    print("\n" + "-" * 100 + "\n")
# Out:
# The UNDP portfolio globally during the 2022 to 2025 Strategic Plan includes 398 active energy-related projects across 132 countries. The total budget for these projects is 4.23 billion USD, targeting 82.5 million direct beneficiaries. This includes 16.8 million from VF projects and 65 million from non-VF projects.
#
# Of those directly benefiting, 52.4 million are gaining access to clean electricity, and 2.73 million are gaining access to clean cooking. Additionally, 27.3 million people benefit from productive uses of energy, including 11.4 million in Health Services, 5.36 million in Water Services, and 4.39 million in Transportation and E-mobility Services. 108 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in RBLAC during the 2022 to 2025 Strategic Plan includes 48 active energy-related projects across 24 countries. The total budget for these projects is 1.51 billion USD, targeting 1.72 million direct beneficiaries. This includes 349,000 from VF projects and 1.37 million from non-VF projects.
#
# Of those directly benefiting, 237,000 are gaining access to clean electricity, and 89,500 are gaining access to clean cooking. Additionally, 1.39 million people benefit from productive uses of energy, including 1.2 million in Transportation and E-mobility Services, 102,000 in Agriculture and Food System, and 45,400 in Water Services. 17 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in RBA during the 2022 to 2025 Strategic Plan includes 130 active energy-related projects across 43 countries. The total budget for these projects is 1.43 billion USD, targeting 37.1 million direct beneficiaries. This includes 4.99 million from VF projects and 32.1 million from non-VF projects.
#
# Of those directly benefiting, 20.1 million are gaining access to clean electricity, and 2.29 million are gaining access to clean cooking. Additionally, 14.7 million people benefit from productive uses of energy, including 9.08 million in Health Services, 5.04 million in Water Services, and 174,000 in Energy Infrastructure Services. 29 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in RBAS during the 2022 to 2025 Strategic Plan includes 47 active energy-related projects across 16 countries. The total budget for these projects is 241 million USD, targeting 11.9 million direct beneficiaries. This includes 3.13 million from VF projects and 8.82 million from non-VF projects.
#
# Of those directly benefiting, 8.5 million are gaining access to clean electricity, and 92,400 are gaining access to clean cooking. Additionally, 3.35 million people benefit from productive uses of energy, including 1.42 million in Transportation and E-mobility Services, 1.17 million in Energy Infrastructure Services, and 474,000 in Health Services. 9 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in RBEC during the 2022 to 2025 Strategic Plan includes 74 active energy-related projects across 19 countries. The total budget for these projects is 508 million USD, targeting 12.8 million direct beneficiaries. This includes 1.04 million from VF projects and 11.7 million from non-VF projects.
#
# Of those directly benefiting, 10.5 million are gaining access to clean electricity, and 171 are gaining access to clean cooking. Additionally, 2.25 million people benefit from productive uses of energy, including 1.11 million in Energy Infrastructure Services, 328,000 in Transportation and E-mobility Services, and 6,970 in Education Services. 19 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in RBAP during the 2022 to 2025 Strategic Plan includes 92 active energy-related projects across 27 countries. The total budget for these projects is 485 million USD, targeting 14.4 million direct beneficiaries. This includes 7.24 million from VF projects and 6.56 million from non-VF projects.
#
# Of those directly benefiting, 8.51 million are gaining access to clean electricity, and 257,000 are gaining access to clean cooking. Additionally, 5.67 million people benefit from productive uses of energy, including 1.83 million in Health Services, 1.45 million in Energy Infrastructure Services, and 1.43 million in Transportation and E-mobility Services. 29 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in SIDS during the 2022 to 2025 Strategic Plan includes 49 active energy-related projects across 22 countries. The total budget for these projects is 238 million USD, targeting 3.51 million direct beneficiaries. This includes 1.13 million from VF projects and 2.38 million from non-VF projects.
#
# Of those directly benefiting, 1.67 million are gaining access to clean electricity, and 174,000 are gaining access to clean cooking. Additionally, 1.67 million people benefit from productive uses of energy, including 970,000 in Health Services, 190,000 in Water Services, and 181,000 in Transportation and E-mobility Services. 17 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in LDCs during the 2022 to 2025 Strategic Plan includes 133 active energy-related projects across 45 countries. The total budget for these projects is 1.52 billion USD, targeting 38.2 million direct beneficiaries. This includes 1.41 million from VF projects and 36.2 million from non-VF projects.
#
# Of those directly benefiting, 18.9 million are gaining access to clean electricity, and 2.53 million are gaining access to clean cooking. Additionally, 16.7 million people benefit from productive uses of energy, including 10.1 million in Health Services, 5.1 million in Water Services, and 673,000 in Transportation and E-mobility Services. 24 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in LLDCs during the 2022 to 2025 Strategic Plan includes 108 active energy-related projects across 31 countries. The total budget for these projects is 587 million USD, targeting 18.8 million direct beneficiaries. This includes 5.02 million from VF projects and 13.2 million from non-VF projects.
#
# Of those directly benefiting, 9.9 million are gaining access to clean electricity, and 605,000 are gaining access to clean cooking. Additionally, 8.28 million people benefit from productive uses of energy, including 7.37 million in Health Services, 328,000 in Transportation and E-mobility Services, and 114,000 in Energy Infrastructure Services. 25 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in Africa during the 2022 to 2025 Strategic Plan includes 155 active energy-related projects across 51 countries. The total budget for these projects is 1.49 billion USD, targeting 39.1 million direct beneficiaries. This includes 6.54 million from VF projects and 32.5 million from non-VF projects.
#
# Of those directly benefiting, 21.1 million are gaining access to clean electricity, and 2.38 million are gaining access to clean cooking. Additionally, 15.6 million people benefit from productive uses of energy, including 9.08 million in Health Services, 5.06 million in Water Services, and 1.1 million in Energy Infrastructure Services. 35 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in Sahel during the 2022 to 2025 Strategic Plan includes 32 active energy-related projects across 10 countries. The total budget for these projects is 373 million USD, targeting 1.57 million direct beneficiaries. This includes 64,100 from VF projects and 1.5 million from non-VF projects.
#
# Of those directly benefiting, 787,000 are gaining access to clean electricity, and 353,000 are gaining access to clean cooking. Additionally, 428,000 people benefit from productive uses of energy, including 174,000 in Energy Infrastructure Services, 32,000 in Health Services, and 28,400 in Education Services. 5 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
#
# The UNDP portfolio in Crisis during the 2022 to 2025 Strategic Plan includes 43 active energy-related projects across 12 countries. The total budget for these projects is 2.42 billion USD, targeting 42.9 million direct beneficiaries. This includes 339,000 from VF projects and 42.5 million from non-VF projects.
#
# Of those directly benefiting, 28.5 million are gaining access to clean electricity, and 1.93 million are gaining access to clean cooking. Additionally, 12.4 million people benefit from productive uses of energy, including 5.69 million in Health Services, 5.03 million in Water Services, and 1.24 million in Energy Infrastructure Services. 4 projects also include outputs related to supporting policy or regulatory frameworks, capacity building, or other system benefits that provide indirect benefits.
#
# ----------------------------------------------------------------------------------------------------
